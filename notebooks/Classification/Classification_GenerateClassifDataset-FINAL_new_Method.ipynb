# %%
import os
import glob
import json
import numpy as np
from tqdm.notebook import tqdm

from astropy.io import fits
from astropy.wcs import WCS
from astropy.wcs.utils import skycoord_to_pixel
from astropy.coordinates import SkyCoord
import astropy.units as u
from astropy.coordinates import Angle

# from sunpy.physics.differential_rotation import diff_rot, solar_rotate_coordinate
from sunpy.coordinates import frames , transformations

from copy import deepcopy

import concurrent.futures
from itertools import repeat
import multiprocessing

from matplotlib import rc
import matplotlib.patches as patches 
import matplotlib.pyplot as plt
import matplotlib.cm as cm

import cv2
import skimage.io as io

import ipywidgets as widgets
# %matplotlib widget

import importlib
import tracking_utilities as utils #import the module here, so that it can be reloaded.
importlib.reload(utils)
import Class2Bbox as c2bb
importlib.reload(c2bb)


import MeanShift as MS
import clustering_utilities as c_utils

# %reload_ext autoreload
# %autoreload 2
# Out:
# WARNING: AstropyDeprecationWarning: The private astropy._erfa module has been made into its own package, pyerfa, which is a dependency of astropy and can be imported directly using "import erfa" [astropy._erfa]

# %% [markdown]
# # Process Predictions

# %%
class NpEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        if isinstance(obj, np.int64):
            return int(obj)
        if isinstance(obj, np.floating):
            return float(obj)
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        if isinstance(obj, np.bool_):
            return bool(obj)
        return super(NpEncoder, self).default(obj)

# %%
# wl_dir = "/globalscratch/users/n/s/nsayez/deepsun_bioblue/ManualAnnotation/image"
wl_dir = "/globalscratch/users/n/s/nsayez/Classification_dataset/2002-2019_2/all"  
# wl_dir = "/globalscratch/users/n/s/nsayez/Classification_dataset/2002-2019/all"  
# wl_dir = "/Users/nielssayez/Documents/Deepsun/Classification_dataset/2002-2019/all"  
# wl_dir = "/Users/nielssayez/Documents/Deepsun/Classification_dataset/ManualAnnotation/"  
wl_list = sorted(glob.glob(os.path.join(wl_dir, '**/*.FTS'),recursive=True))
# wl_basenames = [ os.path.basename(wl) for wl in wl_list ]
wl_basenames = [ os.path.basename(wl).split('.')[0] for wl in wl_list ]


masks_dir = '/globalscratch/users/n/s/nsayez/Classification_dataset/2002-2019_2/T425-T375-T325_fgbg'
# masks_dir = '/globalscratch/users/n/s/nsayez/Classification_dataset/2002-2019/feb2023/T425-T375-T325_fgbg'
# masks_dir = '/home/ucl/elen/nsayez/bio-blueprints/outputs/2023-01-22/01-18-26_2013-15_UNet_T425_T375_T325_StepLR_epoch_1_run0/predictions_4TTA_ManualAnnotation'
# masks_dir = '/globalscratch/users/n/s/nsayez/deepsun_bioblue/ManualAnnotation/GroundTruth'
# masks_dir = '/globalscratch/users/n/s/nsayez/Classification_dataset/2002-2019/T400-T350-Alternating_pen_um'
# masks_dir = '/Users/nielssayez/Documents/Deepsun/Classification_dataset/ManualAnnotation/GroundTruth'

sqlite_db_path = "/globalscratch/users/n/s/nsayez/Classification_dataset/drawings_sqlite.sqlite"
# sqlite_db_path = "/Users/nielssayez/Documents/Deepsun/Classification_dataset/drawings_sqlite.sqlite"
database = sqlite_db_path
print(len(wl_list), )
# Out:
# 3150

# %%
# wl_basenames

# %%
db_drawings_datetimes = [c_utils.db_string_to_datetime(item[0]) for item in c_utils.get_unique_drawing_datetimes(database,'drawings')]
dr_basenames = [c_utils.datetime_to_drawing_name(item) for item in db_drawings_datetimes]

# %%
huge_db_dict = c_utils.wl_list2dbGroups(wl_list[:], dr_basenames, database)
# print(list(huge_db_dict.items())[0])
# Out:
#   0%|          | 0/3150 [00:00<?, ?it/s]

# %%
# # root_dir = '/Users/nielssayez/Documents/Deepsun/Classification_dataset'
# root_dir = '/globalscratch/users/n/s/nsayez/Classification_dataset'

# # tmp = root_dir+'/2002-2019/T400_transunet_wl_list2dbGroups_Classification.json'
# tmp = root_dir+'/2002-2019/jan2023/wl_list2dbGroups_Classification.json'
# # tmp = root_dir+'/ManualAnnotation/wl_list2dbGroups_Classification.json'

# root_dir = './json_output'
# # root_dir = '/globalscratch/users/n/s/nsayez/Classification_dataset'
# tmp = root_dir+'/ManualAnnotation/wl_list2dbGroups_Classification.json'


# root_dir = '/globalscratch/users/n/s/nsayez/Classification_dataset/2002-2019/feb2023'
root_dir = '/globalscratch/users/n/s/nsayez/Classification_dataset/2002-2019_2/'
tmp = root_dir+'/wl_list2dbGroups_Classification.json'

# %%
import json
print(tmp)
with open(tmp, 'w') as f:
    json.dump(huge_db_dict, f, cls=NpEncoder)
# Out:
# /globalscratch/users/n/s/nsayez/Classification_dataset/2002-2019_2//wl_list2dbGroups_Classification.json

# %%
import json
with open(tmp, 'r') as f:
    huge_db_dict = json.load(f)

# %%
# indexes of images that should not be taken into account as the segmentation is really bad
# rotten_list = [ ]
rotten_list = [
    
    37,38,39,40,52, 64,65,69,70,
    
    72,97,99,100,101,102,103,104,142,159,160,161,169,187,190,211,212,218,264,300,312,314,316,319,322,327,339,
    343,353,356,387,408,413,414,418,424,425,448,473,474,493,512,508,611,614,666,675,696,726,330,747,750,758,
    761,784,804,823,832,840,855,914,935,940,948,990,1013,
    
    1025,1039,1040,1089,1172,1303,1332,1345,1397,1409,1413,1414,1421,1440,1444,1468,1469,1488,1576,1646,1692,
    1735,1815,1840,1867,1893,1900,1905,1919,1924,1925,1930,1953,1969,1992,
    
    2007,2039,2043,2045,2049,2050,2078,2121,2133,2143,2185,2208,2220,2254,2266,2272,2298,2344,3262,3274,2375,
    2445,2454,2468,2492,2494,2495,2500,2501,2503,2516,2518,2536,2568,2574,2598,2604,2633,2635,2749,2763,2815,
    2818,2820,2821,2834,2835,2851,2857,2867,2896,2899,2848,2951,2952,2956,2964,2980,2981,2994,
    
    3018,3092,3093,3097,3099,3101,3106,3118,3122,3123,3124,3140,3148
    
    
]
# rotten_list = [                    
#                     69,75,93,94,201,203,311,315,337,341,
#                     403,409,420,441,613,615,668,726,743,
#                     755,778,779,976,996,
                        
#                     1036,1066,1081,1138,1255,1296,1337,1379,1398,1471,
#                     1688,1735,1823,1925,1958,1989,1990,1995,
    
#                     2018,2030,2073,2078,2104,2139,2151,2204,2205,2206,2230,2300,
#                     2312,2325,2327,2349,2376,2452,2460,2461,2559,2673,2778,
#                     2790,2793,2826,2836,2894,2897,2962,
    
#                     3035,3142,3172,3178,3196,3217,3224,3242,3292,3296,
#                     3312,3317,3335,3353,3389,3390,3415,3431,3510,3535,
#                     3551,3571,3614,3664,3720,
#               ]
print(len(rotten_list))
# Out:
# 183

# %%
print(len(huge_dict.keys()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 print(len(huge_dict.keys()))
#
# NameError: name 'huge_dict' is not defined

# %%
import json
with open(root_dir+'/meanshift_Classification.json', 'w') as f:
    json.dump(huge_dict, f, cls=NpEncoder)

# %%
import json
with open(root_dir+'/meanshift_Classification.json', 'r') as f:
    huge_dict = json.load(f)
print(len(huge_dict.keys()))
# Out:
# 3653

# %%
huge_dict = {}

# %%
def generate_batch(lst, batch_size):
    """  Yields bacth of specified size """
    if batch_size<=0:
       return
    for i in range(0, len(lst), batch_size):
        yield lst[i : i + batch_size]
        
# [len(batch) for batch in generate_batch(wl_list, 100)]

# %%
import multiprocessing as mp

look_distance = .1  # How far to look for neighbours.
kernel_bandwidthLon = .35  # Longitude Kernel parameter.
kernel_bandwidthLat = .08  # Latitude Kernel parameter.
n_iterations = 20 # Number of iterations

# num_cpu = 15
# num_cpu = 7
num_cpu = multiprocessing.cpu_count() // 2

input_type = 'confidence_map'
# input_type = 'mask'

print(num_cpu)

for batch in generate_batch(range(len(wl_list)), 400):
    idx_start, idx_end = batch[0], batch[-1]
#     if idx_start < 2000:
#         continue

    print(idx_start, '-->', idx_end)
    
    
    with concurrent.futures.ProcessPoolExecutor(max_workers=int(num_cpu)) as executor:
    #     with concurrent.futures.ProcessPoolExecutor(max_workers=int(num_cpu)) as executor:
#     with concurrent.futures.ThreadPoolExecutor(max_workers=int(num_cpu)) as executor:
#     with mp.Pool(num_cpu) as executor:
        for result_key, result_dict in tqdm(executor.map(c_utils.process_one_image, 
                                                                    wl_list[idx_start:idx_end],
                                                                    repeat(huge_db_dict),
                                                                    repeat(deepcopy(huge_dict)),
                                                                    repeat(wl_list),
                                                                    repeat(rotten_list),
                                                                    repeat(masks_dir),
                                                                    repeat(look_distance),
                                                                    repeat(kernel_bandwidthLon),
                                                                    repeat(kernel_bandwidthLat),
                                                                    repeat(n_iterations),
                                                                    repeat(input_type),)
#                                                                     chunksize=max(round(len(wl_list[idx_start:idx_end])//num_cpu),1
                                                                , 
                                                    ):
                    if not len(list(result_dict.keys())) == 0:
#                         print(result_key)
                        huge_dict[result_key] = deepcopy(result_dict)
# Out:
# 32
# 0 --> 399
# 0it [00:00, ?it/s]
# 400 --> 799
# 0it [00:00, ?it/s]
# 800 --> 1199
# 0it [00:00, ?it/s]
# 1200 --> 1599
# 0it [00:00, ?it/s]
# 1600 --> 1999
# 0it [00:00, ?it/s]
# 2000 --> 2399
# 0it [00:00, ?it/s]
# 2400 --> 2799
# 0it [00:00, ?it/s]
# 2800 --> 3149
# 0it [00:00, ?it/s]

# %%
# import multiprocessing as mp

# look_distance = .1  # How far to look for neighbours.
# kernel_bandwidthLon = .35  # Longitude Kernel parameter.
# kernel_bandwidthLat = .08  # Latitude Kernel parameter.
# n_iterations = 20 # Number of iterations

# # num_cpu = 20
# # num_cpu = 7
# num_cpu = multiprocessing.cpu_count() - 4

# input_type = 'confidence_map'
# # input_type = 'mask'



# for batch in generate_batch(range(len(wl_list)), 100):
#     idx_start, idx_end = batch[0], batch[-1]
#     if idx_start < 3600:
#         continue
#     print(idx_start, '-->', idx_end)
    
    
#     with concurrent.futures.ProcessPoolExecutor(max_workers=int(num_cpu)) as executor:
#     #     with concurrent.futures.ProcessPoolExecutor(max_workers=int(num_cpu)) as executor:
#     #     with concurrent.futures.ThreadPoolExecutor(max_workers=int(num_cpu)) as executor:
# #     with mp.Pool(num_cpu) as executor:
#                 for result_key, result_dict in tqdm(executor.map(c_utils.process_one_image, 
#                                                                     wl_list[idx_start:idx_end],
#                                                                     repeat(huge_db_dict),
#                                                                     repeat(huge_dict),
#                                                                     repeat(wl_list),
#                                                                     repeat(rotten_list),
#                                                                     repeat(masks_dir),
#                                                                     repeat(look_distance),
#                                                                     repeat(kernel_bandwidthLon),
#                                                                     repeat(kernel_bandwidthLat),
#                                                                     repeat(n_iterations),
#                                                                     repeat(input_type),
# #                                                                     chunksize=max(round(len(wl_list[idx_start:idx_end])//num_cpu),1)
#                                                                 ), 
#                                                     ):
#                     if not len(list(result_dict.keys())) == 0:
#                         print(result_key)
#                         huge_dict[result_key] = deepcopy(result_dict)

# %%
# look_distance = .1  # How far to look for neighbours.
# kernel_bandwidthLon = .35  # Longitude Kernel parameter.
# kernel_bandwidthLat = .08  # Latitude Kernel parameter.
# n_iterations = 20 # Number of iterations

# num_cpu = 20
# # num_cpu = 48
# # num_cpu = multiprocessing.cpu_count()

# input_type = 'confidence_map'
# # input_type = 'mask'

# for batch in generate_batch(wl_list, 100):
#     with concurrent.futures.ProcessPoolExecutor(max_workers=int(num_cpu)) as executor:
# #     with concurrent.futures.ProcessPoolExecutor(max_workers=int(num_cpu)) as executor:
# #     with concurrent.futures.ThreadPoolExecutor(max_workers=int(num_cpu)) as executor:
#             for result_key, result_dict in tqdm(executor.map(c_utils.process_one_image, 
#                                                                 batch[:],
#                                                                 repeat(huge_db_dict),
#                                                                 repeat(huge_dict),
#                                                                 repeat(wl_list),
#                                                                 repeat(rotten_list),
#                                                                 repeat(masks_dir),
#                                                                 repeat(look_distance),
#                                                                 repeat(kernel_bandwidthLon),
#                                                                 repeat(kernel_bandwidthLat),
#                                                                 repeat(n_iterations),
#                                                                 repeat(input_type),
#                                                                 chunksize=100), 
#                                                 ):
#                 if not len(list(result_dict.keys())) == 0:
#                     print(result_key)
#                     huge_dict[result_key] = deepcopy(result_dict)

# %%
for im in tqdm(wl_list[:]):
    result_key, result_dict = c_utils.process_one_image(
                                                                im,
                                                                huge_db_dict,
                                                                huge_dict,
                                                                wl_list,
                                                                rotten_list,
                                                                masks_dir,
                                                                look_distance,
                                                                kernel_bandwidthLon,
                                                                kernel_bandwidthLat,
                                                                n_iterations,
                                                                input_type
                                                        )
#     print(result_key)
    if not len(list(result_dict.keys())) == 0:
        huge_dict[result_key] = result_dict
# Out:
#   0%|          | 0/3750 [00:00<?, ?it/s]

# %%
# huge_dict

# %%
import json
# with open('/Users/nielssayez/Documents/Deepsun/Classification_dataset/ManualAnnotation/meanshift_Classification.json', 'w') as f:
# with open(root_dir+'/2002-2019/jan2023/meanshift_Classification.json', 'w') as f:
# with open(root_dir+'/ManualAnnotation/meanshift_Classification.json', 'w') as f:
# with open(root_dir+'/meanshift_Classification.json', 'w') as f:
with open(root_dir+'/test/meanshift_Classification.json', 'w') as f:
    json.dump(huge_dict, f, cls=NpEncoder)

# %%
import json
# with open('/Users/nielssayez/Documents/Deepsun/Classification_dataset/ManualAnnotation/meanshift_Classification.json', 'r') as f:
# with open(root_dir+'/2002-2019/jan2023/meanshift_Classification.json', 'r') as f:
# with open(root_dir+'/ManualAnnotation/meanshift_Classification.json', 'r') as f:
with open(root_dir+'/test/meanshift_Classification.json', 'r') as f:
    huge_dict = json.load(f)

# %%
print(len(list(huge_dict.keys())))
# Out:
# 2961

# %%
print()

# %% [markdown]
# # View Results

# %%
colors = ['tab:blue','tab:orange','tab:green','tab:red',
          'tab:purple','tab:brown','tab:pink','tab:gray',
          'tab:olive','tab:cyan']

from matplotlib.colors import ListedColormap, LinearSegmentedColormap   
cmap_gt = cm.autumn
cmap_gt = cmap_gt(range(255))
cmap_gt = ListedColormap([(0, 0, 0, 0), *cmap_gt])

cmap = plt.get_cmap('autumn')
cmap.set_under((0,0,0,0))

def my_refresh(value):
    ccc = fig.gca()
    xlims0 = ccc.get_xlim()
    ylims0 = ccc.get_ylim()
    
    ccc.set_visible(False) 
    
    basename = list(huge_dict.keys())[img_selector.value]
    tmp_idx = wl_basenames.index(basename)
    wl = wl_list[tmp_idx]
     
    #####################
    
    cur_db_dict = huge_db_dict[basename]
    
    group_list = cur_db_dict["group_list"]
    drawing_radius_mm = cur_db_dict["dr_radius_mm"]
    drawing_radius_px = cur_db_dict["dr_radius_px"]
    date2 = cur_db_dict["dr_date"]
    date = cur_db_dict["wl_date"] 
    
    #####################
    m, h = utils.open_and_add_celestial(wl_list[tmp_idx])
#     m, h = utils.open_and_add_celestial2(wl_list[tmp_idx], date_obs=date)
#     print(h)

    corrected = False
    
    if not 'DATE-OBS' in h:
        m, h = utils.open_and_add_celestial2(wl_list[tmp_idx], date_obs=date)
        corrected = True
        
    wcs = WCS(h)
    wcs.heliographic_observer = m.observer_coordinate
    origin = m.data.shape[0]//2, m.data.shape[1]//2
    
    if input_type == "mask":
        mask = io.imread(os.path.join(masks_dir,basename+".png"))
    elif input_type == "confidence_map":
        mask = np.load(os.path.join(masks_dir,basename+"_proba_map.npy"))
        
    print(m.data.shape , mask.shape)
    
        # raise AssertionError("Not implemented yet")
#     mask[mask>0] = 1 

    m_rot = m.rotate(angle=-h["SOLAR_P0"] * u.deg)
    top_right = SkyCoord( 1000 * u.arcsec, 1000 * u.arcsec, frame=m_rot.coordinate_frame)
    bottom_left = SkyCoord(-1000 * u.arcsec, -1000 * u.arcsec, frame=m_rot.coordinate_frame)
    m_rot_submap = m_rot.submap(bottom_left, top_right=top_right)
    m_rot_submap_shape = m_rot_submap.data.shape
    m_rot_shape = m_rot.data.shape
    deltashapeX = np.abs(m_rot_shape[0]-m_rot_submap_shape[0])
    deltashapeY = np.abs(m_rot_shape[1]-m_rot_submap_shape[1]) 

    h2 = m_rot_submap.fits_header 

    h2.append(('CTYPE1', 'HPLN-TAN'))
    h2.append(('CTYPE2', 'HPLT-TAN'))
    wcs2 = WCS(h2)
    wcs2.heliographic_observer = m_rot_submap.observer_coordinate
    origin = m_rot_submap.data.shape[0]//2, m_rot_submap.data.shape[1]//2
    
#     if not m_rot_submap.date == date:
#         m_rot_submap.date = date
#         print(m_rot_submap.date)
    
    axClustering = fig.add_subplot(projection=m_rot_submap)
    m_rot_submap.plot(axes=axClustering, interpolation='None')
    m_rot_submap.draw_grid()   
    
    disp_mask = c_utils.rotate_CV_bound(mask, angle=h["SOLAR_P0"], interpolation=cv2.INTER_NEAREST) #rotate(mask, angle=h["SOLAR_P0"], reshape=True)
    disp_mask = disp_mask[deltashapeX//2:disp_mask.shape[0]-deltashapeX//2,
                          deltashapeY//2:disp_mask.shape[1]-deltashapeY//2] 
    axClustering.imshow(disp_mask, cmap=cmap, interpolation="None", alpha=.5 )
#     axClustering.imshow(disp_mask, cmap=cmap, interpolation="None", alpha=.5, vmin=.001 )
    
    axClustering.set_title(axClustering.get_title()+ f' [corrected: {corrected}]'  + f'-> drawing: {date2}' )
    
    ####################
    dr_obstime = date+'.000'  
    all_sks = []
    all_pixels = []
    for item in group_list:
        cur_sk = SkyCoord(item["Longitude"]*u.rad, item["Latitude"]*u.rad , frame=frames.HeliographicCarrington,
                      obstime=dr_obstime, observer="earth") 
        coords_wl = skycoord_to_pixel(cur_sk, wcs2, origin=0)
        all_sks.append(cur_sk)
        all_pixels.append(coords_wl)
        
    bboxes, bboxes_wl, rectangles, rectangles_wl = c_utils.grouplist2bboxes_and_rectangles(group_list, 
                                                                                   drawing_radius_px,
                                                                                   h["SOLAR_R"],
                                                                                   all_pixels)
    for cur_sk in all_sks:
        axClustering.plot_coord(cur_sk, "o", color='b', markersize=2)

    for i, r in enumerate(rectangles_wl):
        axClustering.add_patch(r)
        if areas_cb.value:
            axClustering.text(bboxes_wl[i][0]+3, bboxes_wl[i][1]+3, 
                          f' {group_list[i]["McIntosh"]} : {group_list[i]["area_muHem"]}',color='b') 
    
    ####################
    
    sunspots_sk, sunspots_areas = c_utils.get_sunspots3(h,m, mask>0, sky_coords=True)
    sk_Lon = sunspots_sk.lon.rad
    sk_Lat = sunspots_sk.lat.rad
    sk_LatLon = np.stack((sk_Lat,sk_Lon),axis=1)
    
    nan_indexes = np.unique(np.argwhere(np.isnan(sk_LatLon))[:,0])
    clean = (~np.isnan(sk_Lon) & ~np.isnan(sk_Lat))
    if len(nan_indexes) > 0:
        sunspots_sk = sunspots_sk[clean]
        sunspots_areas = (np.array(sunspots_areas)[clean]).tolist()
        sk_LatLon = sk_LatLon [clean]
    
    cur_dict = huge_dict[basename]
    
    ######################
    if ms_cb.value:
        cur_ms = cur_dict["meanshift"]

        ms_centroids = np.array(cur_ms['centroids'])
        ms_areas = np.array(cur_ms['areas'])
        ms_groups = np.array(cur_ms['groups'])
        
        my_ms = MS.Mean_Shift(look_distance, kernel_bandwidthLon, kernel_bandwidthLat, sunspots_sk.radius.km[0] ,  n_iterations)
        ##########
        my_ms.set_centroids(ms_centroids)
        # my_ms.fit(sk_LatLon, sunspots_areas)
        # ms_centroids = my_ms.centroids
        ###########
        ms_classifications = my_ms.predict(sk_LatLon)

        # print(m.date, '  ', date )
        sk_sequ_meanshift = SkyCoord(ms_centroids[:,1]*u.rad, ms_centroids[:,0]*u.rad , frame=frames.HeliographicCarrington,
                              obstime=m.date, observer="earth")
        
        pix_centers_meanshift = skycoord_to_pixel(sk_sequ_meanshift, wcs2, origin=0)

        for i, sk in enumerate(sk_sequ_meanshift):
                axClustering.plot_coord(sk, "X", color=colors[i%len(colors)], markersize=8)
                if areas_cb.value:
                    axClustering.text(pix_centers_meanshift[0][i], pix_centers_meanshift[1][i],  '%.2f' % ms_areas[i] ,va='top',c=colors[i%len(colors)])
        for i in range(len(sk_LatLon)):
            c = colors[ms_classifications[i]%len(colors)]
            axClustering.plot_coord(sunspots_sk[i], "o", color=c, markersize=2)

look_distance = .1 # How far to look for neighbours.
kernel_bandwidthLon = .3  # Longitude Kernel parameter.
kernel_bandwidthLat = .08  # Latitude Kernel parameter.
n_iterations = 20 # Number of iterations


input_type = "confidence_map"
# input_type = "mask"

huge_dict = {k: huge_dict[k] for k in sorted(list(huge_dict.keys()))}

db_drawings_datetimes = [c_utils.db_string_to_datetime(item[0]) for item in c_utils.get_unique_drawing_datetimes(database,'drawings')]
dr_basenames = [c_utils.datetime_to_drawing_name(item) for item in db_drawings_datetimes]

# print(huge_dict.keys())
    
img_selector = widgets.IntSlider(value=158, min=0, max=len(list(huge_dict.keys()))-1)
areas_cb = widgets.Checkbox(value=False, description="Show Areas")
km_cb = widgets.Checkbox(value=False, description="Show KMeans")
ms_cb = widgets.Checkbox(value=True, description="Show MeanShift")

img_selector.observe(my_refresh)
areas_cb.observe(my_refresh)
ms_cb.observe(my_refresh)
km_cb.observe(my_refresh)

plt.ioff()
fig, ax_widget = plt.subplots(nrows=1, ncols=1, figsize=(8,8))
my_refresh(0)
plt.ion()

widgets.VBox([widgets.HBox([img_selector, areas_cb, ms_cb]),fig.canvas])
# Out:
# (2048, 2048) (2048, 2048)
# VBox(children=(HBox(children=(IntSlider(value=158, max=2960), Checkbox(value=False, description='Show Areas'),…
# (2048, 2048) (2048, 2048)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/miniconda3/envs/new-bioblue/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:676, in Widget._handle_msg(self, msg)
#     674         if 'buffer_paths' in data:
#     675             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 676         self.set_state(state)
#     678 # Handle a state request.
#     679 elif method == 'request_state':
#
# File ~/miniconda3/envs/new-bioblue/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:540, in Widget.set_state(self, sync_data)
#     536 """Called when a state is received from the front-end."""
#     537 # The order of these context managers is important. Properties must
#     538 # be locked when the hold_trait_notification context manager is
#     539 # released and notifications are fired.
# --> 540 with self._lock_property(**sync_data), self.hold_trait_notifications():
#     541     for name in sync_data:
#     542         if name in self.keys:
#
# File ~/miniconda3/envs/new-bioblue/lib/python3.8/contextlib.py:113, in _GeneratorContextManager.__enter__(self)
#     111 del self.args, self.kwds, self.func
#     112 try:
# --> 113     return next(self.gen)
#     114 except StopIteration:
#     115     raise RuntimeError("generator didn't yield") from None
#
# File ~/miniconda3/envs/new-bioblue/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:624, in Widget._lock_property(self, **properties)
#     615 @contextmanager
#     616 def _lock_property(self, **properties):
#     617     """Lock a property-value pair.
#     618
#     619     The value should be the JSON state of the property.
#    (...)
#     622     flawed.  In the future we may want to look into buffering state changes
#     623     back to the front-end."""
# --> 624     self._property_lock = properties
#     625     try:
#     626         yield
#
# File ~/miniconda3/envs/new-bioblue/lib/python3.8/site-packages/traitlets/traitlets.py:606, in TraitType.__set__(self, obj, value)
#     604     raise TraitError('The "%s" trait is read-only.' % self.name)
#     605 else:
# --> 606     self.set(obj, value)
#
# File ~/miniconda3/envs/new-bioblue/lib/python3.8/site-packages/traitlets/traitlets.py:595, in TraitType.set(self, obj, value)
#     591     silent = False
#     592 if silent is not True:
#     593     # we explicitly compare silent to True just in case the equality
#     594     # comparison above returns something other than True/False
# --> 595     obj._notify_trait(self.name, old_value, new_value)
#
# File ~/miniconda3/envs/new-bioblue/lib/python3.8/site-packages/traitlets/traitlets.py:1219, in HasTraits._notify_trait(self, name, old_value, new_value)
#    1218 def _notify_trait(self, name, old_value, new_value):
# -> 1219     self.notify_change(Bunch(
#    1220         name=name,
#    1221         old=old_value,
#    1222         new=new_value,
#    1223         owner=self,
#    1224         type='change',
#    1225     ))
#
# File ~/miniconda3/envs/new-bioblue/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:606, in Widget.notify_change(self, change)
#     603     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     604         # Send new state to front-end
#     605         self.send_state(key=name)
# --> 606 super(Widget, self).notify_change(change)
#
# File ~/miniconda3/envs/new-bioblue/lib/python3.8/site-packages/traitlets/traitlets.py:1229, in HasTraits.notify_change(self, change)
#    1227 def notify_change(self, change):
#    1228     """Notify observers of a change event"""
# -> 1229     return self._notify_observers(change)
#
# File ~/miniconda3/envs/new-bioblue/lib/python3.8/site-packages/traitlets/traitlets.py:1266, in HasTraits._notify_observers(self, event)
#    1263 elif isinstance(c, EventHandler) and c.name is not None:
#    1264     c = getattr(self, c.name)
# -> 1266 c(event)
#
# Input In [17], in my_refresh(value)
#      80 axClustering = fig.add_subplot(projection=m_rot_submap)
#      81 m_rot_submap.plot(axes=axClustering, interpolation='None')
# ---> 82 m_rot_submap.draw_grid()
#      84 disp_mask = c_utils.rotate_CV_bound(mask, angle=h["SOLAR_P0"], interpolation=cv2.INTER_NEAREST) #rotate(mask, angle=h["SOLAR_P0"], reshape=True)
#      85 disp_mask = disp_mask[deltashapeX//2:disp_mask.shape[0]-deltashapeX//2,
#      86                       deltashapeY//2:disp_mask.shape[1]-deltashapeY//2]
#
# File ~/miniconda3/envs/new-bioblue/lib/python3.8/site-packages/astropy/units/decorators.py:302, in QuantityInput.__call__.<locals>.wrapper(*func_args, **func_kwargs)
#     300 # Call the original function with any equivalencies in force.
#     301 with add_enabled_equivalencies(self.equivalencies):
# --> 302     return_ = wrapped_function(*func_args, **func_kwargs)
#     304 # Return
#     305 ra = wrapped_signature.return_annotation
#
# File ~/miniconda3/envs/new-bioblue/lib/python3.8/site-packages/sunpy/map/mapbase.py:1788, in GenericMap.draw_grid(self, axes, grid_spacing, annotate, **kwargs)
#    1786     axes = wcsaxes_compat.gca_wcs(self.wcs)
#    1787 if not wcsaxes_compat.is_wcsaxes(axes):
# -> 1788     raise TypeError("Overlay grids can only be plotted on WCSAxes plots.")
#    1789 return wcsaxes_compat.wcsaxes_heliographic_overlay(axes,
#    1790                                                    grid_spacing=grid_spacing,
#    1791                                                    annotate=annotate,
#    1792                                                    **kwargs)
#
# TypeError: Overlay grids can only be plotted on WCSAxes plots.

# %%
from scipy.ndimage import rotate as rotate_image

def rotate_img_opencv(image, angle, interpolation):
    (h, w) = image.shape[:2]
    (cX, cY) = (w // 2, h // 2)

    M = cv2.getRotationMatrix2D((cX, cY), angle, 1.0)
    rotated = cv2.warpAffine(image, M, (w, h))
    return rotated

def my_refresh(value):
    
    basename = list(huge_dict.keys())[img_selector.value]
    tmp_idx = wl_basenames.index(basename)
    wl = wl_list[tmp_idx]
    
    m, h = utils.open_and_add_celestial(wl_list[tmp_idx])
     
    if input_type == "mask":
        mask = io.imread(os.path.join(masks_dir,basename+".png"))
    elif input_type == "confidence_map":
#         print('here')
        mask = np.load(os.path.join(masks_dir,basename+"_proba_map.npy"))
    
    ax2_widget[0].imshow(m.data, cmap='gray')
    ax2_widget[0].imshow(mask, cmap=cmap, alpha = .5, vmin=.1)
    ax2_widget[0].set_title(basename)
    ax2_widget[0].invert_yaxis()
    
    m_rot = m.rotate(angle=-h["SOLAR_P0"] * u.deg)
    top_right = SkyCoord( 1000 * u.arcsec, 1000 * u.arcsec, frame=m_rot.coordinate_frame)
    bottom_left = SkyCoord(-1000 * u.arcsec, -1000 * u.arcsec, frame=m_rot.coordinate_frame)
    m_rot_submap = m_rot.submap(bottom_left, top_right=top_right)
    m_rot_submap_shape = m_rot_submap.data.shape
    m_rot_shape = m_rot.data.shape
    deltashapeX = np.abs(m_rot_shape[0]-m_rot_submap_shape[0])
    deltashapeY = np.abs(m_rot_shape[1]-m_rot_submap_shape[1]) 
    
    
#     rot_img = rotate_image(m_rot_submap.data, angle=h["SOLAR_P0"]) #rotate(mask, angle=h["SOLAR_P0"], reshape=True)
#     disp_mask = rotate_image(mask, angle=h["SOLAR_P0"]) #rotate(mask, angle=h["SOLAR_P0"], reshape=True)

    rot_img = c_utils.rotate_CV_bound(m_rot_submap.data, angle=h["SOLAR_P0"], interpolation=cv2.INTER_NEAREST) #rotate(mask, angle=h["SOLAR_P0"], reshape=True)
    disp_mask = c_utils.rotate_CV_bound(mask, angle=h["SOLAR_P0"], interpolation=cv2.INTER_NEAREST) #rotate(mask, angle=h["SOLAR_P0"], reshape=True)
    disp_mask = disp_mask[deltashapeX//2:disp_mask.shape[0]-deltashapeX//2,
                          deltashapeY//2:disp_mask.shape[1]-deltashapeY//2] 
    
    ax2_widget[1].imshow(m_rot_submap.data, cmap='gray')
    ax2_widget[1].imshow(disp_mask, cmap=cmap, alpha = .5, vmin=.1)
    ax2_widget[1].set_title(h["SOLAR_P0"])
    ax2_widget[1].invert_yaxis()
    

input_type = "confidence_map"

look_distance = .1 # How far to look for neighbours.
kernel_bandwidthLon = .3  # Longitude Kernel parameter.
kernel_bandwidthLat = .08  # Latitude Kernel parameter.
n_iterations = 20 # Number of iterations


db_drawings_datetimes = [c_utils.db_string_to_datetime(item[0]) for item in c_utils.get_unique_drawing_datetimes(database,'drawings')]
dr_basenames = [c_utils.datetime_to_drawing_name(item) for item in db_drawings_datetimes]

# print(huge_dict.keys())
huge_dict = {k: huge_dict[k] for k in sorted(list(huge_dict.keys()))}

    
img_selector = widgets.IntSlider(value=3000, min=0, max=len(list(huge_dict.keys()))-1)
mask_cb = widgets.Checkbox(value=True, description="Show Masks")

img_selector.observe(my_refresh)

plt.ioff()
fig2, ax2_widget = plt.subplots(nrows=1, ncols=2, figsize=(10,4))
my_refresh(0)
plt.ion()

widgets.VBox([widgets.HBox([img_selector]),fig2.canvas])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 76>()
#      74 plt.ioff()
#      75 fig2, ax2_widget = plt.subplots(nrows=1, ncols=2, figsize=(10,4))
# ---> 76 my_refresh(0)
#      77 plt.ion()
#      79 widgets.VBox([widgets.HBox([img_selector]),fig2.canvas])
#
# Input In [11], in my_refresh(value)
#      23     mask = np.load(os.path.join(masks_dir,basename+"_proba_map.npy"))
#      25 ax2_widget[0].imshow(m.data, cmap='gray')
# ---> 26 ax2_widget[0].imshow(mask, cmap=cmap, alpha = .5, vmin=.1)
#      27 ax2_widget[0].set_title(basename)
#      28 ax2_widget[0].invert_yaxis()
#
# NameError: name 'cmap' is not defined

# %% [markdown]
# # Associate groups

# %%
image_out_dict = {}
image_out_dict_stats = {}

# for basename in list(huge_dict.keys())[3400:3401]:
# for basename in list(huge_dict.keys())[:1]:
#     cur_image_dict = huge_dict[basename]
# for basename in ["UPH20120912082643",]:
for basename in tqdm(list(huge_dict.keys())[:]):
# for basename in ["UPH20170623120332"]:
    cur_image_dict = huge_dict[basename]
    
    angle = cur_image_dict["SOLAR_P0"]
    deltashapeX = cur_image_dict["deltashapeX"]
    deltashapeY = cur_image_dict["deltashapeY"]
    
    drawing_radius_px = huge_db_dict[basename]["dr_radius_px"]
    
    group_list = cur_image_dict['db']
    
    
    ms_dict = cur_image_dict['meanshift']
    
    centroids = np.array(ms_dict["centroids"])
    centroids_px = np.array(ms_dict["centroids_px"])
#     print('centroids_px', centroids_px)
    
#     db_bboxes = grouplist2bboxes(group_list, drawing_radius_px)
    db_classes = [{"Zurich":item['Zurich'], "McIntosh":item['McIntosh'] } for item in group_list]
    db_bboxes = [np.array(item['bbox_wl']) for item in group_list]
    db_centers_px = np.array([[(b[2]+b[0])/2,(b[3]+b[1])/2] for b in db_bboxes])
    
#     print("db_centers_px", db_centers_px)
#     print("db_bboxes", db_bboxes)
    
        
    # check that current bbox is does not overlap any
    isolated_bboxes_bool = np.array(c_utils.get_intersecting_db_bboxes(db_bboxes)) == 0
    isolated_bboxes_indices = np.where(isolated_bboxes_bool == True)[0]
#     print("isolated_bboxes_bool",isolated_bboxes_bool)
#     print(isolated_bboxes_indices)
    
    cur_out_stats = {
        # General info
        'num_DB_groups':len(db_bboxes),
        'num_MS_groups':len(centroids_px),
        'num_DB_isolated_groups':len(isolated_bboxes_indices),
        'num_DB_overlaping_bboxes':len(db_bboxes) - len(isolated_bboxes_indices),
        # MS with DB matching info
        "num_MSmatchesDB":0,
        # MS with DB rejection info
        "num_noMS_but_DB_reject":0,
        "num_singleMS_multipleDB_reject":0,
        "num_oneDBbbox_multipleMSoverlap_ambiguity_reject":0,
        # MS with DB no match info
        "num_noDB_but_MS":0,
        }
    cur_out_groups = []
    for i, (db_bbox, db_center, db_class) in enumerate(
                                            zip([db_bboxes[a] for a in isolated_bboxes_indices.tolist() ],
                                                [db_centers_px[a] for a in isolated_bboxes_indices.tolist()],
                                                [db_classes[a] for a in isolated_bboxes_indices.tolist()],
                                               )):
        
        
        ms_centroids, ms_members = centroids_px, ms_dict['groups_px']
        
        intersect = c_utils.contains_ms_groups(db_bbox, db_center, ms_centroids, ms_members)
        
        if sum(intersect) == 0: # Il n'y a eu aucune détection dans cette zone
            cur_out_stats['num_noMS_but_DB_reject'] += 1
            pass
        elif sum(intersect) == 1: # il n'y a de l'overlap qu'avec un seul groupe meanshift            
#             print('hit')
            idx = intersect.index(True)
#             print(idx)
            # vérifier que le groupe meanshift n'intersecte aucune autre bbox
            num_intersections = np.sum(c_utils.count_group_intersections(ms_members[idx], db_bboxes))
            if num_intersections > 1:
                cur_out_stats['num_singleMS_multipleDB_reject'] += 1
                continue
            
            Rmm = huge_db_dict[basename]['dr_radius_mm']
            R_pixel = huge_db_dict[basename]['dr_radius_px']
            sun_center = huge_db_dict[basename]['dr_center_px']
            dr_pixpos = np.array([group_list[i]['posx'], group_list[i]['posy']])
            
            angular_excentricity =  c_utils.get_angle2(dr_pixpos, R_pixel, sun_center)
            
            cur_group_dict={
                            "centroid_px": centroids_px[idx],
                            "centroid_Lat": centroids[idx][0],
                            "centroid_Lon": centroids[idx][1],
                            "angular_excentricity_rad": angular_excentricity,
                            "angular_excentricity_deg": np.rad2deg(angular_excentricity),
                            "Zurich":   db_class["Zurich"],
                            "McIntosh": db_class["McIntosh"],
                            "members": ms_members[idx],
                            "members_mean_px": np.mean(ms_members[idx], axis=0),
                           }
            
            
            cur_out_groups.append(cur_group_dict)
            cur_out_stats['num_MSmatchesDB'] += 1

        else: # db_bbox intersecte plusieurs groupes meanshift
            cur_out_stats['num_oneDBbbox_multipleMSoverlap_ambiguity_reject'] += 1
            pass
            
    if len(cur_out_groups) > 0:
        image_out_dict[basename] = { "angle": angle,
                                     "deltashapeX":deltashapeX,
                                     "deltashapeY":deltashapeY,
                                     "groups": cur_out_groups,
                                   }

    # count the number of MS groups that do not have any overlap with the DB
    num_intersections_per_group = [np.sum(c_utils.count_group_intersections(ms_members[idx], db_bboxes)) for idx in range(len(ms_members))]
    num_MS_without_DB_overlap = len(np.where(np.array(num_intersections_per_group) == 0)[0])
    cur_out_stats['num_noDB_but_MS'] = num_MS_without_DB_overlap
    
    image_out_dict_stats[basename] = cur_out_stats

    

print('num_images: ', len(list(image_out_dict.keys())))
num_groups = 0
for k,v in image_out_dict.items():
    num_groups += len(v['groups'])
print("num_groups: ",num_groups)
# print(image_out_dict)
# Out:
#   0%|          | 0/2961 [00:00<?, ?it/s]
# num_images:  1856
# num_groups:  3889

# %%
# Plot some stats
# General info
num_DB_groups_per_image = np.array([item['num_DB_groups'] for k,item in image_out_dict_stats.items()])
num_MS_groups_per_image = np.array([item['num_MS_groups'] for k,item in image_out_dict_stats.items()])

diff_num_groups = num_DB_groups_per_image - num_MS_groups_per_image # should be shown on histogram , closer to 0 is better

# number of isolated DB groups per image and mean number in dataset
num_isolated_DB_groups = np.array([v['num_DB_isolated_groups'] for k,v in image_out_dict_stats.items()])

# numbers of rejects due to single MS group overlapping multiple DB groups (# minimize this)
num_singleMS_multipleDB_reject = np.array([v['num_singleMS_multipleDB_reject'] for k,v in image_out_dict_stats.items()])
# numbers of rejects due to single DB group overlapping multiple MS groups (# minimize this)
num_oneDBbbox_multipleMSoverlap_ambiguity_reject = np.array([v['num_oneDBbbox_multipleMSoverlap_ambiguity_reject'] for k,v in image_out_dict_stats.items()])
# numbers of rejects due to no MS group overlapping DB group (# cannot do anything to this, examples are discarded)
num_noMS_but_DB_reject = np.array([v['num_noMS_but_DB_reject'] for k,v in image_out_dict_stats.items()])

num_optimizable_rejects = num_singleMS_multipleDB_reject + num_oneDBbbox_multipleMSoverlap_ambiguity_reject
num_rejects_all = num_optimizable_rejects + num_noMS_but_DB_reject

# rate of optimizable rejects
rate_optimizable_rejects = num_optimizable_rejects / num_rejects_all

#rate of 


# Numbers over whole dataset
num_DB_groups = np.sum(num_DB_groups_per_image)
num_MS_groups = np.sum(num_MS_groups_per_image)

num_isolated_DB_groups_total = np.sum(num_isolated_DB_groups) # cannot do anything to this, maximum value possible
rate_isolated_DB_groups_total = num_isolated_DB_groups_total / num_DB_groups
num_overlapping_DB_groups_total = num_DB_groups - num_isolated_DB_groups_total # cannot do anything to this, examples are discarded
rate_overlapping_DB_groups_total = num_overlapping_DB_groups_total / num_DB_groups

num_singleMS_multipleDB_reject_total = np.sum(num_singleMS_multipleDB_reject) # minimize this
num_oneDBbbox_multipleMSoverlap_ambiguity_reject_total = np.sum(num_oneDBbbox_multipleMSoverlap_ambiguity_reject) # minimize this

# %%
# Plot some stats
# General info
num_DB_groups_per_image = np.array([item['num_DB_groups'] for k,item in image_out_dict_stats.items()])
num_MS_groups_per_image = np.array([item['num_MS_groups'] for k,item in image_out_dict_stats.items()])

diff_num_groups = num_DB_groups_per_image - num_MS_groups_per_image # should be shown on histogram , closer to 0 is better

# number of isolated DB groups per image and mean number in dataset
num_isolated_DB_groups = np.array([v['num_DB_isolated_groups'] for k,v in image_out_dict_stats.items()])
mean_num_isolated_DB_groups = np.mean(num_isolated_DB_groups) # not very useful
rate_isolated_DB_groups = num_isolated_DB_groups / num_DB_groups_per_image # not very useful
mean_rate_isolated_DB_groups = np.mean(rate_isolated_DB_groups) # not very useful
std_rate_isolated_DB_groups = np.std(rate_isolated_DB_groups) # not very useful

# Numbers over whole dataset
num_DB_groups = np.sum(num_DB_groups_per_image)
num_MS_groups = np.sum(num_MS_groups_per_image)
num_isolated_DB_groups_total = np.sum(num_isolated_DB_groups)
rate_isolated_DB_groups_total = num_isolated_DB_groups_total / num_DB_groups

#


# number of MS groups without DB overlap per image
num_MS_groups_without_DB_overlap = np.array([v['num_noDB_but_MS'] for k,v in image_out_dict_stats.items()])
mean_num_MS_groups_without_DB_overlap = np.mean(num_MS_groups_without_DB_overlap) # not very useful
rate_MS_groups_without_DB_overlap = num_MS_groups_without_DB_overlap / num_MS_groups_per_image
mean_rate_MS_groups_without_DB_overlap = np.mean(rate_MS_groups_without_DB_overlap)
std_rate_MS_groups_without_DB_overlap = np.std(rate_MS_groups_without_DB_overlap)

#number of DB groups without MS overlap per image
num_DB_groups_without_MS_overlap = np.array([v['num_noMS_but_DB_reject'] for k,v in image_out_dict_stats.items()])
mean_num_DB_groups_without_MS_overlap = np.mean(num_DB_groups_without_MS_overlap) # not very useful
rate_DB_groups_without_MS_overlap = num_DB_groups_without_MS_overlap / num_DB_groups_per_image
mean_rate_DB_groups_without_MS_overlap = np.mean(rate_DB_groups_without_MS_overlap)
std_rate_DB_groups_without_MS_overlap = np.std(rate_DB_groups_without_MS_overlap)


# total number of rejects per image
total_rejects = np.sum([v['num_noMS_but_DB_reject'] + 
                        v['num_singleMS_multipleDB_reject'] +
                        v['num_oneDBbbox_multipleMSoverlap_ambiguity_reject'] 
                        for k,v in image_out_dict_stats.items()])

# # total number of DB groups 
# reject_rates = total_rejects / 

# # mean percentage of rejects per image
# mean_percentage_rejects = np.mean([ (( v['num_noMS_but_DB_reject'] +
#                                       v['num_singleMS_multipleDB_reject'] + 
#                                       v['num_oneDBbbox_multipleMSoverlap_ambiguity_reject']
#                                     )/ v['num_DB_groups'] * 100) if v['num_DB_groups'] > 0 else 0
#                                     for k,v in image_out_dict_stats.items()])

# %%
# print("len(huge_dict.keys()): ", len(huge_dict.keys()))
# print("len(image_out_dict.keys()): ", len(image_out_dict.keys()))

# # get the keys in huge_dict not present in image_out_dict

# missing_keys = []
# for k in huge_dict.keys():
#     # print(k)
#     if k not in image_out_dict.keys():
#         missing_keys.append(k)
# print("missing_keys: ", missing_keys)

#print the number of groups per image in huge_db_dict
for i,(k,v) in enumerate(huge_db_dict.items()):
    # print(v)
    # print(huge_dict[k].keys())
    # print(huge_dict[k]["meanshift"]['centroids'], len(huge_dict[k]["meanshift"]['centroids']))
    idx =  i
    img_name = k
    db_num_groups = len(v['group_list'])
    found_groups = len(huge_dict[k]["meanshift"]['centroids']) if k in huge_dict.keys() else 0
    matched_groups = len(image_out_dict[k]['groups']) if k in image_out_dict.keys() else 0

    
    print(f'idx {idx}: {img_name} DB num_groups: {db_num_groups} Found Groups: {found_groups} Matched Groups: {matched_groups}')
    # print( f'idx {i}: ', k, "DB num_groups:" ,len(v['group_list']), 'Matched Groups', len(image_out_dict[k]['groups']) )

# for k,v in image_out_dict.items():
#     print(k, len(v['groups']))
# Out:
# idx 0: UPH20020424160712 DB num_groups: 13 Found Groups: 16 Matched Groups: 2
# idx 1: UPH20020427094522 DB num_groups: 11 Found Groups: 11 Matched Groups: 2
# idx 2: UPH20020428170429 DB num_groups: 7 Found Groups: 11 Matched Groups: 1
# idx 3: UPH20020502111048 DB num_groups: 12 Found Groups: 11 Matched Groups: 5
# idx 4: UPH20020507112606 DB num_groups: 14 Found Groups: 18 Matched Groups: 2
# idx 5: UPH20020508155035 DB num_groups: 15 Found Groups: 9 Matched Groups: 4
# idx 6: UPH20020513152850 DB num_groups: 10 Found Groups: 12 Matched Groups: 1
# idx 7: UPH20020515170013 DB num_groups: 7 Found Groups: 9 Matched Groups: 1
# idx 8: UPH20020521184732 DB num_groups: 9 Found Groups: 8 Matched Groups: 2
# idx 9: UPH20020527140851 DB num_groups: 12 Found Groups: 12 Matched Groups: 2
# idx 10: UPH20020529170600 DB num_groups: 11 Found Groups: 5 Matched Groups: 1
# idx 11: UPH20020531163352 DB num_groups: 11 Found Groups: 14 Matched Groups: 6
# idx 12: UPH20020604170808 DB num_groups: 13 Found Groups: 16 Matched Groups: 8
# idx 13: UPH20020606181039 DB num_groups: 12 Found Groups: 21 Matched Groups: 2
# idx 14: UPH20020610163057 DB num_groups: 6 Found Groups: 17 Matched Groups: 5
# idx 15: UPH20020611135151 DB num_groups: 5 Found Groups: 13 Matched Groups: 4
# idx 16: UPH20020615122825 DB num_groups: 6 Found Groups: 6 Matched Groups: 0
# idx 17: UPH20020616130258 DB num_groups: 7 Found Groups: 1 Matched Groups: 0
# idx 18: UPH20020617113114 DB num_groups: 5 Found Groups: 10 Matched Groups: 3
# idx 19: UPH20020618140442 DB num_groups: 8 Found Groups: 13 Matched Groups: 3
# idx 20: UPH20020619092827 DB num_groups: 7 Found Groups: 16 Matched Groups: 2
# idx 21: UPH20020624134812 DB num_groups: 5 Found Groups: 15 Matched Groups: 4
# idx 22: UPH20020625104123 DB num_groups: 7 Found Groups: 7 Matched Groups: 6
# idx 23: UPH20020626091858 DB num_groups: 7 Found Groups: 7 Matched Groups: 6
# idx 24: UPH20020627113238 DB num_groups: 7 Found Groups: 5 Matched Groups: 5
# idx 25: UPH20020702144558 DB num_groups: 6 Found Groups: 4 Matched Groups: 3
# idx 26: UPH20020704144358 DB num_groups: 7 Found Groups: 5 Matched Groups: 3
# idx 27: UPH20020708121058 DB num_groups: 5 Found Groups: 5 Matched Groups: 2
# idx 28: UPH20020709112703 DB num_groups: 7 Found Groups: 5 Matched Groups: 2
# idx 29: UPH20020711130952 DB num_groups: 5 Found Groups: 4 Matched Groups: 2
# idx 30: UPH20020712114832 DB num_groups: 5 Found Groups: 3 Matched Groups: 2
# idx 31: UPH20020717111600 DB num_groups: 6 Found Groups: 4 Matched Groups: 2
# idx 32: UPH20020717145814 DB num_groups: 6 Found Groups: 3 Matched Groups: 2
# idx 33: UPH20020719115611 DB num_groups: 5 Found Groups: 6 Matched Groups: 1
# idx 34: UPH20020722094133 DB num_groups: 6 Found Groups: 6 Matched Groups: 6
# idx 35: UPH20020722141926 DB num_groups: 6 Found Groups: 6 Matched Groups: 6
# idx 36: UPH20020725115821 DB num_groups: 8 Found Groups: 10 Matched Groups: 6
# idx 37: UPH20020726144437 DB num_groups: 8 Found Groups: 0 Matched Groups: 0
# idx 38: UPH20020729100724 DB num_groups: 10 Found Groups: 0 Matched Groups: 0
# idx 39: UPH20020730095940 DB num_groups: 9 Found Groups: 0 Matched Groups: 0
# idx 40: UPH20020801153851 DB num_groups: 9 Found Groups: 0 Matched Groups: 0
# idx 41: UPH20020807095804 DB num_groups: 7 Found Groups: 7 Matched Groups: 5
# idx 42: UPH20020811110146 DB num_groups: 9 Found Groups: 6 Matched Groups: 3
# idx 43: UPH20020812121245 DB num_groups: 9 Found Groups: 9 Matched Groups: 6
# idx 44: UPH20020813133753 DB num_groups: 10 Found Groups: 12 Matched Groups: 3
# idx 45: UPH20020814113452 DB num_groups: 16 Found Groups: 12 Matched Groups: 6
# idx 46: UPH20020815105238 DB num_groups: 15 Found Groups: 13 Matched Groups: 7
# idx 47: UPH20020816140222 DB num_groups: 13 Found Groups: 11 Matched Groups: 6
# idx 48: UPH20020817112508 DB num_groups: 13 Found Groups: 10 Matched Groups: 7
# idx 49: UPH20020818111917 DB num_groups: 12 Found Groups: 10 Matched Groups: 5
# idx 50: UPH20020819114432 DB num_groups: 11 Found Groups: 10 Matched Groups: 5
# idx 51: UPH20020822163444 DB num_groups: 8 Found Groups: 9 Matched Groups: 8
# idx 52: UPH20020824163051 DB num_groups: 9 Found Groups: 0 Matched Groups: 0
# idx 53: UPH20020825144923 DB num_groups: 9 Found Groups: 6 Matched Groups: 3
# idx 54: UPH20030217095047 DB num_groups: 1 Found Groups: 1 Matched Groups: 0
# idx 55: UPH20030218103944 DB num_groups: 2 Found Groups: 3 Matched Groups: 2
# idx 56: UPH20030219131320 DB num_groups: 3 Found Groups: 4 Matched Groups: 3
# idx 57: UPH20030220114300 DB num_groups: 4 Found Groups: 4 Matched Groups: 3
# idx 58: UPH20030220142828 DB num_groups: 4 Found Groups: 5 Matched Groups: 4
# idx 59: UPH20030221111050 DB num_groups: 4 Found Groups: 3 Matched Groups: 1
# idx 60: UPH20030221143222 DB num_groups: 4 Found Groups: 4 Matched Groups: 2
# idx 61: UPH20030224112608 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 62: UPH20030225121107 DB num_groups: 3 Found Groups: 4 Matched Groups: 3
# idx 63: UPH20030225152130 DB num_groups: 3 Found Groups: 5 Matched Groups: 3
# idx 64: UPH20030227093842 DB num_groups: 5 Found Groups: 0 Matched Groups: 0
# idx 65: UPH20030227154557 DB num_groups: 5 Found Groups: 0 Matched Groups: 0
# idx 66: UPH20030228115519 DB num_groups: 4 Found Groups: 4 Matched Groups: 3
# idx 67: UPH20030303141905 DB num_groups: 6 Found Groups: 5 Matched Groups: 1
# idx 68: UPH20030306154128 DB num_groups: 5 Found Groups: 5 Matched Groups: 2
# idx 69: UPH20030307091752 DB num_groups: 8 Found Groups: 0 Matched Groups: 0
# idx 70: UPH20030308094154 DB num_groups: 7 Found Groups: 0 Matched Groups: 0
# idx 71: UPH20030308102413 DB num_groups: 7 Found Groups: 7 Matched Groups: 3
# idx 72: UPH20030309105831 DB num_groups: 8 Found Groups: 0 Matched Groups: 0
# idx 73: UPH20030309132615 DB num_groups: 12 Found Groups: 6 Matched Groups: 2
# idx 74: UPH20030310121110 DB num_groups: 4 Found Groups: 11 Matched Groups: 3
# idx 75: UPH20030313091921 DB num_groups: 4 Found Groups: 4 Matched Groups: 2
# idx 76: UPH20030313102733 DB num_groups: 4 Found Groups: 4 Matched Groups: 3
# idx 77: UPH20030313143439 DB num_groups: 5 Found Groups: 4 Matched Groups: 3
# idx 78: UPH20030314095523 DB num_groups: 5 Found Groups: 5 Matched Groups: 4
# idx 79: UPH20030314135410 DB num_groups: 5 Found Groups: 4 Matched Groups: 4
# idx 80: UPH20030315105230 DB num_groups: 6 Found Groups: 6 Matched Groups: 4
# idx 81: UPH20030316110645 DB num_groups: 5 Found Groups: 3 Matched Groups: 2
# idx 82: UPH20030317135451 DB num_groups: 3 Found Groups: 3 Matched Groups: 2
# idx 83: UPH20030318094021 DB num_groups: 3 Found Groups: 3 Matched Groups: 2
# idx 84: UPH20030318112813 DB num_groups: 3 Found Groups: 2 Matched Groups: 2
# idx 85: UPH20030318145440 DB num_groups: 3 Found Groups: 3 Matched Groups: 2
# idx 86: UPH20030319094901 DB num_groups: 3 Found Groups: 4 Matched Groups: 3
# idx 87: UPH20030319104948 DB num_groups: 3 Found Groups: 4 Matched Groups: 2
# idx 88: UPH20030319131046 DB num_groups: 3 Found Groups: 2 Matched Groups: 1
# idx 89: UPH20030320121257 DB num_groups: 3 Found Groups: 3 Matched Groups: 1
# idx 90: UPH20030320142807 DB num_groups: 3 Found Groups: 2 Matched Groups: 1
# idx 91: UPH20030322092533 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 92: UPH20030323103126 DB num_groups: 3 Found Groups: 0 Matched Groups: 0
# idx 93: UPH20030324104119 DB num_groups: 4 Found Groups: 4 Matched Groups: 3
# idx 94: UPH20030324131910 DB num_groups: 4 Found Groups: 4 Matched Groups: 3
# idx 95: UPH20030325153111 DB num_groups: 5 Found Groups: 5 Matched Groups: 3
# idx 96: UPH20030326120511 DB num_groups: 6 Found Groups: 4 Matched Groups: 3
# idx 97: UPH20030327104039 DB num_groups: 7 Found Groups: 0 Matched Groups: 0
# idx 98: UPH20030327132207 DB num_groups: 6 Found Groups: 4 Matched Groups: 4
# idx 99: UPH20030507075243 DB num_groups: 6 Found Groups: 0 Matched Groups: 0
# idx 100: UPH20030507095017 DB num_groups: 4 Found Groups: 0 Matched Groups: 0
# idx 101: UPH20030508115345 DB num_groups: 2 Found Groups: 0 Matched Groups: 0
# idx 102: UPH20030510082940 DB num_groups: 2 Found Groups: 0 Matched Groups: 0
# idx 103: UPH20030511104543 DB num_groups: 3 Found Groups: 0 Matched Groups: 0
# idx 104: UPH20030512105208 DB num_groups: 3 Found Groups: 0 Matched Groups: 0
# idx 105: UPH20030815120426 DB num_groups: 3 Found Groups: 9 Matched Groups: 3
# idx 106: UPH20030816105800 DB num_groups: 4 Found Groups: 17 Matched Groups: 1
# idx 107: UPH20030819134728 DB num_groups: 5 Found Groups: 9 Matched Groups: 1
# idx 108: UPH20030820104617 DB num_groups: 6 Found Groups: 7 Matched Groups: 0
# idx 109: UPH20030821122342 DB num_groups: 4 Found Groups: 8 Matched Groups: 4
# idx 110: UPH20030824105551 DB num_groups: 5 Found Groups: 9 Matched Groups: 2
# idx 111: UPH20030825142709 DB num_groups: 7 Found Groups: 9 Matched Groups: 2
# idx 112: UPH20030826121017 DB num_groups: 6 Found Groups: 10 Matched Groups: 3
# idx 113: UPH20030827170037 DB num_groups: 8 Found Groups: 10 Matched Groups: 3
# idx 114: UPH20030828142227 DB num_groups: 10 Found Groups: 11 Matched Groups: 3
# idx 115: UPH20030901142703 DB num_groups: 5 Found Groups: 10 Matched Groups: 2
# idx 116: UPH20030902115350 DB num_groups: 4 Found Groups: 10 Matched Groups: 1
# idx 117: UPH20030903093236 DB num_groups: 4 Found Groups: 7 Matched Groups: 2
# idx 118: UPH20030903155556 DB num_groups: 5 Found Groups: 8 Matched Groups: 2
# idx 119: UPH20030904103212 DB num_groups: 6 Found Groups: 8 Matched Groups: 2
# idx 120: UPH20030904144230 DB num_groups: 5 Found Groups: 11 Matched Groups: 2
# idx 121: UPH20030905101453 DB num_groups: 3 Found Groups: 9 Matched Groups: 1
# idx 122: UPH20030908100137 DB num_groups: 1 Found Groups: 9 Matched Groups: 1
# idx 123: UPH20030908100209 DB num_groups: 1 Found Groups: 7 Matched Groups: 1
# idx 124: UPH20030913104046 DB num_groups: 2 Found Groups: 7 Matched Groups: 1
# idx 125: UPH20030914110711 DB num_groups: 3 Found Groups: 9 Matched Groups: 2
# idx 126: UPH20030915123933 DB num_groups: 4 Found Groups: 8 Matched Groups: 1
# idx 127: UPH20030915124044 DB num_groups: 4 Found Groups: 7 Matched Groups: 1
# idx 128: UPH20030920104946 DB num_groups: 5 Found Groups: 10 Matched Groups: 2
# idx 129: UPH20030923113052 DB num_groups: 4 Found Groups: 10 Matched Groups: 1
# idx 130: UPH20030924122000 DB num_groups: 4 Found Groups: 11 Matched Groups: 1
# idx 131: UPH20030925121446 DB num_groups: 4 Found Groups: 10 Matched Groups: 1
# idx 132: UPH20030926104413 DB num_groups: 4 Found Groups: 10 Matched Groups: 1
# idx 133: UPH20030927124006 DB num_groups: 5 Found Groups: 11 Matched Groups: 1
# idx 134: UPH20030930114737 DB num_groups: 6 Found Groups: 18 Matched Groups: 1
# idx 135: UPH20031002160813 DB num_groups: 6 Found Groups: 11 Matched Groups: 3
# idx 136: UPH20031004113511 DB num_groups: 5 Found Groups: 7 Matched Groups: 1
# idx 137: UPH20031005100313 DB num_groups: 5 Found Groups: 8 Matched Groups: 0
# idx 138: UPH20031007144251 DB num_groups: 4 Found Groups: 8 Matched Groups: 1
# idx 139: UPH20031008102350 DB num_groups: 4 Found Groups: 10 Matched Groups: 1
# idx 140: UPH20031011111412 DB num_groups: 5 Found Groups: 11 Matched Groups: 2
# idx 141: UPH20031012103430 DB num_groups: 4 Found Groups: 7 Matched Groups: 2
# idx 142: UPH20031014111726 DB num_groups: 1 Found Groups: 0 Matched Groups: 0
# idx 143: UPH20031015111314 DB num_groups: 1 Found Groups: 5 Matched Groups: 1
# idx 144: UPH20031016101532 DB num_groups: 2 Found Groups: 9 Matched Groups: 2
# idx 145: UPH20031017102154 DB num_groups: 3 Found Groups: 9 Matched Groups: 0
# idx 146: UPH20031018122016 DB num_groups: 3 Found Groups: 8 Matched Groups: 0
# idx 147: UPH20031019114042 DB num_groups: 3 Found Groups: 8 Matched Groups: 1
# idx 148: UPH20031020114111 DB num_groups: 3 Found Groups: 8 Matched Groups: 2
# idx 149: UPH20031022112917 DB num_groups: 3 Found Groups: 10 Matched Groups: 1
# idx 150: UPH20031023114414 DB num_groups: 3 Found Groups: 3 Matched Groups: 0
# idx 151: UPH20031024154620 DB num_groups: 2 Found Groups: 11 Matched Groups: 2
# idx 152: UPH20031025121117 DB num_groups: 3 Found Groups: 9 Matched Groups: 3
# idx 153: UPH20031027112548 DB num_groups: 6 Found Groups: 11 Matched Groups: 4
# idx 154: UPH20031028105241 DB num_groups: 7 Found Groups: 13 Matched Groups: 4
# idx 155: UPH20031029095034 DB num_groups: 8 Found Groups: 13 Matched Groups: 6
# idx 156: UPH20031103115113 DB num_groups: 5 Found Groups: 12 Matched Groups: 3
# idx 157: UPH20031105102800 DB num_groups: 2 Found Groups: 7 Matched Groups: 1
# idx 158: UPH20031106101416 DB num_groups: 1 Found Groups: 9 Matched Groups: 1
# idx 159: UPH20031107102802 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 160: UPH20031108094700 DB num_groups: 2 Found Groups: 0 Matched Groups: 0
# idx 161: UPH20031108094728 DB num_groups: 2 Found Groups: 0 Matched Groups: 0
# idx 162: UPH20031109101957 DB num_groups: 3 Found Groups: 11 Matched Groups: 1
# idx 163: UPH20031109102435 DB num_groups: 3 Found Groups: 9 Matched Groups: 1
# idx 164: UPH20031109112104 DB num_groups: 3 Found Groups: 8 Matched Groups: 1
# idx 165: UPH20031110104818 DB num_groups: 3 Found Groups: 12 Matched Groups: 1
# idx 166: UPH20031111095853 DB num_groups: 3 Found Groups: 8 Matched Groups: 0
# idx 167: UPH20031113104802 DB num_groups: 2 Found Groups: 8 Matched Groups: 0
# idx 168: UPH20031115105925 DB num_groups: 3 Found Groups: 7 Matched Groups: 1
# idx 169: UPH20031123153335 DB num_groups: 6 Found Groups: 0 Matched Groups: 0
# idx 170: UPH20031124113246 DB num_groups: 8 Found Groups: 11 Matched Groups: 3
# idx 171: UPH20031203102543 DB num_groups: 7 Found Groups: 9 Matched Groups: 3
# idx 172: UPH20031203102602 DB num_groups: 7 Found Groups: 10 Matched Groups: 3
# idx 173: UPH20031207102948 DB num_groups: 3 Found Groups: 9 Matched Groups: 3
# idx 174: UPH20031208112102 DB num_groups: 3 Found Groups: 10 Matched Groups: 2
# idx 175: UPH20031209104208 DB num_groups: 2 Found Groups: 4 Matched Groups: 0
# idx 176: UPH20031210143638 DB num_groups: 4 Found Groups: 9 Matched Groups: 3
# idx 177: UPH20031212123628 DB num_groups: 3 Found Groups: 9 Matched Groups: 2
# idx 178: UPH20031217120058 DB num_groups: 8 Found Groups: 14 Matched Groups: 6
# idx 179: UPH20031218102310 DB num_groups: 9 Found Groups: 8 Matched Groups: 2
# idx 180: UPH20031219132021 DB num_groups: 7 Found Groups: 12 Matched Groups: 5
# idx 181: UPH20031222103135 DB num_groups: 8 Found Groups: 11 Matched Groups: 4
# idx 182: UPH20040102114504 DB num_groups: 3 Found Groups: 5 Matched Groups: 0
# idx 183: UPH20040103110219 DB num_groups: 3 Found Groups: 1 Matched Groups: 0
# idx 184: UPH20040123122317 DB num_groups: 6 Found Groups: 4 Matched Groups: 0
# idx 185: UPH20040124141018 DB num_groups: 5 Found Groups: 10 Matched Groups: 2
# idx 186: UPH20040125101351 DB num_groups: 2 Found Groups: 8 Matched Groups: 0
# idx 187: UPH20040128152040 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 188: UPH20040129111842 DB num_groups: 2 Found Groups: 6 Matched Groups: 1
# idx 189: UPH20040203140022 DB num_groups: 5 Found Groups: 17 Matched Groups: 3
# idx 190: UPH20040204124239 DB num_groups: 4 Found Groups: 0 Matched Groups: 0
# idx 191: UPH20040207095644 DB num_groups: 2 Found Groups: 8 Matched Groups: 2
# idx 192: UPH20040215095012 DB num_groups: 7 Found Groups: 10 Matched Groups: 4
# idx 193: UPH20040219103425 DB num_groups: 2 Found Groups: 9 Matched Groups: 2
# idx 194: UPH20040220090526 DB num_groups: 3 Found Groups: 7 Matched Groups: 2
# idx 195: UPH20040222121010 DB num_groups: 3 Found Groups: 2 Matched Groups: 0
# idx 196: UPH20040223110153 DB num_groups: 5 Found Groups: 1 Matched Groups: 0
# idx 197: UPH20040224140533 DB num_groups: 4 Found Groups: 9 Matched Groups: 3
# idx 198: UPH20040303133233 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 199: UPH20040313140036 DB num_groups: 3 Found Groups: 10 Matched Groups: 2
# idx 200: UPH20040314091124 DB num_groups: 3 Found Groups: 9 Matched Groups: 2
# idx 201: UPH20040316103752 DB num_groups: 4 Found Groups: 8 Matched Groups: 3
# idx 202: UPH20040317082812 DB num_groups: 5 Found Groups: 8 Matched Groups: 2
# idx 203: UPH20040317131249 DB num_groups: 5 Found Groups: 10 Matched Groups: 3
# idx 204: UPH20040324092814 DB num_groups: 4 Found Groups: 9 Matched Groups: 3
# idx 205: UPH20040411113515 DB num_groups: 1 Found Groups: 7 Matched Groups: 1
# idx 206: UPH20040603141025 DB num_groups: 3 Found Groups: 1 Matched Groups: 0
# idx 207: UPH20040605093529 DB num_groups: 3 Found Groups: 1 Matched Groups: 0
# idx 208: UPH20040606061141 DB num_groups: 4 Found Groups: 2 Matched Groups: 1
# idx 209: UPH20040606084831 DB num_groups: 3 Found Groups: 1 Matched Groups: 0
# idx 210: UPH20040607071024 DB num_groups: 3 Found Groups: 2 Matched Groups: 2
# idx 211: UPH20040609093302 DB num_groups: 3 Found Groups: 0 Matched Groups: 0
# idx 212: UPH20040614080356 DB num_groups: 3 Found Groups: 0 Matched Groups: 0
# idx 213: UPH20040615085817 DB num_groups: 3 Found Groups: 3 Matched Groups: 2
# idx 214: UPH20040616065451 DB num_groups: 5 Found Groups: 6 Matched Groups: 3
# idx 215: UPH20040617072833 DB num_groups: 4 Found Groups: 6 Matched Groups: 2
# idx 216: UPH20040619075152 DB num_groups: 3 Found Groups: 5 Matched Groups: 2
# idx 217: UPH20040619093921 DB num_groups: 3 Found Groups: 6 Matched Groups: 2
# idx 218: UPH20040620074642 DB num_groups: 5 Found Groups: 0 Matched Groups: 0
# idx 219: UPH20040621093728 DB num_groups: 5 Found Groups: 5 Matched Groups: 3
# idx 220: UPH20040623092232 DB num_groups: 3 Found Groups: 2 Matched Groups: 2
# idx 221: UPH20040624081950 DB num_groups: 2 Found Groups: 4 Matched Groups: 0
# idx 222: UPH20040625065352 DB num_groups: 3 Found Groups: 4 Matched Groups: 1
# idx 223: UPH20040626090343 DB num_groups: 2 Found Groups: 3 Matched Groups: 2
# idx 224: UPH20040627095624 DB num_groups: 3 Found Groups: 1 Matched Groups: 1
# idx 225: UPH20040628100855 DB num_groups: 3 Found Groups: 2 Matched Groups: 1
# idx 226: UPH20040629065246 DB num_groups: 3 Found Groups: 1 Matched Groups: 1
# idx 227: UPH20040629092334 DB num_groups: 3 Found Groups: 1 Matched Groups: 1
# idx 228: UPH20040630101841 DB num_groups: 3 Found Groups: 1 Matched Groups: 0
# idx 229: UPH20040701071425 DB num_groups: 2 Found Groups: 3 Matched Groups: 2
# idx 230: UPH20040702134610 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 231: UPH20040703110657 DB num_groups: 2 Found Groups: 2 Matched Groups: 1
# idx 232: UPH20040705104422 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 233: UPH20040706071543 DB num_groups: 1 Found Groups: 0 Matched Groups: 0
# idx 234: UPH20040708070145 DB num_groups: 1 Found Groups: 1 Matched Groups: 0
# idx 235: UPH20040710115927 DB num_groups: 4 Found Groups: 5 Matched Groups: 3
# idx 236: UPH20040711090930 DB num_groups: 4 Found Groups: 3 Matched Groups: 2
# idx 237: UPH20040716105003 DB num_groups: 4 Found Groups: 3 Matched Groups: 3
# idx 238: UPH20040717090105 DB num_groups: 6 Found Groups: 4 Matched Groups: 4
# idx 239: UPH20040718135947 DB num_groups: 5 Found Groups: 5 Matched Groups: 3
# idx 240: UPH20040719074943 DB num_groups: 4 Found Groups: 5 Matched Groups: 4
# idx 241: UPH20040720122857 DB num_groups: 4 Found Groups: 4 Matched Groups: 4
# idx 242: UPH20040721123544 DB num_groups: 4 Found Groups: 4 Matched Groups: 3
# idx 243: UPH20040722080136 DB num_groups: 4 Found Groups: 5 Matched Groups: 4
# idx 244: UPH20040724092652 DB num_groups: 3 Found Groups: 3 Matched Groups: 3
# idx 245: UPH20040726100126 DB num_groups: 4 Found Groups: 3 Matched Groups: 3
# idx 246: UPH20040727074752 DB num_groups: 3 Found Groups: 3 Matched Groups: 3
# idx 247: UPH20040728085541 DB num_groups: 3 Found Groups: 2 Matched Groups: 1
# idx 248: UPH20040729082536 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 249: UPH20040730081507 DB num_groups: 2 Found Groups: 3 Matched Groups: 2
# idx 250: UPH20040731102827 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 251: UPH20040731120934 DB num_groups: 2 Found Groups: 3 Matched Groups: 2
# idx 252: UPH20040801131901 DB num_groups: 2 Found Groups: 3 Matched Groups: 2
# idx 253: UPH20040802075719 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 254: UPH20040803092258 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 255: UPH20040804100654 DB num_groups: 2 Found Groups: 2 Matched Groups: 1
# idx 256: UPH20040805095651 DB num_groups: 1 Found Groups: 2 Matched Groups: 1
# idx 257: UPH20040807094257 DB num_groups: 3 Found Groups: 3 Matched Groups: 3
# idx 258: UPH20040808080926 DB num_groups: 3 Found Groups: 3 Matched Groups: 3
# idx 259: UPH20040809090343 DB num_groups: 3 Found Groups: 9 Matched Groups: 3
# idx 260: UPH20040811083725 DB num_groups: 3 Found Groups: 4 Matched Groups: 3
# idx 261: UPH20040814115409 DB num_groups: 4 Found Groups: 4 Matched Groups: 4
# idx 262: UPH20040815092427 DB num_groups: 4 Found Groups: 4 Matched Groups: 4
# idx 263: UPH20040816081512 DB num_groups: 4 Found Groups: 3 Matched Groups: 2
# idx 264: UPH20040817075947 DB num_groups: 3 Found Groups: 0 Matched Groups: 0
# idx 265: UPH20040818073947 DB num_groups: 4 Found Groups: 5 Matched Groups: 1
# idx 266: UPH20040819092524 DB num_groups: 4 Found Groups: 3 Matched Groups: 1
# idx 267: UPH20040820090457 DB num_groups: 5 Found Groups: 3 Matched Groups: 1
# idx 268: UPH20040821111225 DB num_groups: 4 Found Groups: 5 Matched Groups: 3
# idx 269: UPH20040822102935 DB num_groups: 5 Found Groups: 5 Matched Groups: 2
# idx 270: UPH20040823093007 DB num_groups: 5 Found Groups: 3 Matched Groups: 2
# idx 271: UPH20040824085450 DB num_groups: 3 Found Groups: 5 Matched Groups: 1
# idx 272: UPH20040825102058 DB num_groups: 3 Found Groups: 4 Matched Groups: 1
# idx 273: UPH20040826131352 DB num_groups: 3 Found Groups: 3 Matched Groups: 1
# idx 274: UPH20040828091936 DB num_groups: 3 Found Groups: 3 Matched Groups: 2
# idx 275: UPH20040830075041 DB num_groups: 1 Found Groups: 2 Matched Groups: 0
# idx 276: UPH20040831070440 DB num_groups: 1 Found Groups: 1 Matched Groups: 0
# idx 277: UPH20040902072337 DB num_groups: 1 Found Groups: 2 Matched Groups: 0
# idx 278: UPH20040903072626 DB num_groups: 2 Found Groups: 3 Matched Groups: 1
# idx 279: UPH20040904092509 DB num_groups: 2 Found Groups: 2 Matched Groups: 1
# idx 280: UPH20040905085503 DB num_groups: 5 Found Groups: 4 Matched Groups: 1
# idx 281: UPH20040906080425 DB num_groups: 3 Found Groups: 3 Matched Groups: 0
# idx 282: UPH20040906133514 DB num_groups: 4 Found Groups: 3 Matched Groups: 2
# idx 283: UPH20040907083112 DB num_groups: 3 Found Groups: 3 Matched Groups: 3
# idx 284: UPH20040908075721 DB num_groups: 4 Found Groups: 4 Matched Groups: 2
# idx 285: UPH20040909084520 DB num_groups: 4 Found Groups: 4 Matched Groups: 2
# idx 286: UPH20040910073637 DB num_groups: 4 Found Groups: 5 Matched Groups: 3
# idx 287: UPH20040911094239 DB num_groups: 3 Found Groups: 4 Matched Groups: 2
# idx 288: UPH20040912070211 DB num_groups: 4 Found Groups: 3 Matched Groups: 1
# idx 289: UPH20040914072747 DB num_groups: 1 Found Groups: 2 Matched Groups: 1
# idx 290: UPH20040915081615 DB num_groups: 2 Found Groups: 2 Matched Groups: 1
# idx 291: UPH20040916085634 DB num_groups: 2 Found Groups: 2 Matched Groups: 1
# idx 292: UPH20040917100546 DB num_groups: 2 Found Groups: 2 Matched Groups: 1
# idx 293: UPH20040919082145 DB num_groups: 3 Found Groups: 3 Matched Groups: 3
# idx 294: UPH20040921074217 DB num_groups: 2 Found Groups: 2 Matched Groups: 1
# idx 295: UPH20040925082321 DB num_groups: 2 Found Groups: 1 Matched Groups: 0
# idx 296: UPH20040929090111 DB num_groups: 3 Found Groups: 2 Matched Groups: 1
# idx 297: UPH20041003082807 DB num_groups: 3 Found Groups: 4 Matched Groups: 3
# idx 298: UPH20041004111915 DB num_groups: 3 Found Groups: 4 Matched Groups: 3
# idx 299: UPH20041006144710 DB num_groups: 2 Found Groups: 2 Matched Groups: 1
# idx 300: UPH20041008123526 DB num_groups: 2 Found Groups: 0 Matched Groups: 0
# idx 301: UPH20041009085236 DB num_groups: 1 Found Groups: 1 Matched Groups: 0
# idx 302: UPH20041010085612 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 303: UPH20041011090209 DB num_groups: 0 Found Groups: 5 Matched Groups: 0
# idx 304: UPH20041012103959 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 305: UPH20041013084415 DB num_groups: 2 Found Groups: 3 Matched Groups: 1
# idx 306: UPH20041014080604 DB num_groups: 2 Found Groups: 1 Matched Groups: 0
# idx 307: UPH20041015082722 DB num_groups: 1 Found Groups: 1 Matched Groups: 0
# idx 308: UPH20041017114524 DB num_groups: 3 Found Groups: 12 Matched Groups: 2
# idx 309: UPH20041019090721 DB num_groups: 4 Found Groups: 8 Matched Groups: 2
# idx 310: UPH20041021083859 DB num_groups: 6 Found Groups: 6 Matched Groups: 4
# idx 311: UPH20041022102208 DB num_groups: 6 Found Groups: 7 Matched Groups: 5
# idx 312: UPH20041025143741 DB num_groups: 6 Found Groups: 0 Matched Groups: 0
# idx 313: UPH20041026084101 DB num_groups: 7 Found Groups: 2 Matched Groups: 0
# idx 314: UPH20041027111032 DB num_groups: 7 Found Groups: 0 Matched Groups: 0
# idx 315: UPH20041028085432 DB num_groups: 7 Found Groups: 7 Matched Groups: 7
# idx 316: UPH20041030091033 DB num_groups: 8 Found Groups: 0 Matched Groups: 0
# idx 317: UPH20041030092118 DB num_groups: 8 Found Groups: 6 Matched Groups: 6
# idx 318: UPH20041103131802 DB num_groups: 5 Found Groups: 8 Matched Groups: 3
# idx 319: UPH20041104102806 DB num_groups: 5 Found Groups: 0 Matched Groups: 0
# idx 320: UPH20041105093646 DB num_groups: 4 Found Groups: 7 Matched Groups: 4
# idx 321: UPH20041109102652 DB num_groups: 3 Found Groups: 1 Matched Groups: 1
# idx 322: UPH20041111095910 DB num_groups: 4 Found Groups: 0 Matched Groups: 0
# idx 323: UPH20041113092533 DB num_groups: 3 Found Groups: 3 Matched Groups: 2
# idx 324: UPH20041114113210 DB num_groups: 4 Found Groups: 3 Matched Groups: 2
# idx 325: UPH20041115094430 DB num_groups: 3 Found Groups: 4 Matched Groups: 3
# idx 326: UPH20041119105144 DB num_groups: 5 Found Groups: 4 Matched Groups: 3
# idx 327: UPH20041120092317 DB num_groups: 2 Found Groups: 0 Matched Groups: 0
# idx 328: UPH20041121095421 DB num_groups: 2 Found Groups: 3 Matched Groups: 2
# idx 329: UPH20041122124126 DB num_groups: 3 Found Groups: 2 Matched Groups: 1
# idx 330: UPH20041124093241 DB num_groups: 4 Found Groups: 0 Matched Groups: 0
# idx 331: UPH20041125140513 DB num_groups: 3 Found Groups: 3 Matched Groups: 3
# idx 332: UPH20041130104016 DB num_groups: 3 Found Groups: 5 Matched Groups: 0
# idx 333: UPH20041202095131 DB num_groups: 3 Found Groups: 4 Matched Groups: 3
# idx 334: UPH20041203092556 DB num_groups: 3 Found Groups: 5 Matched Groups: 3
# idx 335: UPH20041204140125 DB num_groups: 3 Found Groups: 4 Matched Groups: 3
# idx 336: UPH20041208142031 DB num_groups: 2 Found Groups: 2 Matched Groups: 1
# idx 337: UPH20041209125608 DB num_groups: 0 Found Groups: 1 Matched Groups: 0
# idx 338: UPH20041214141034 DB num_groups: 1 Found Groups: 2 Matched Groups: 1
# idx 339: UPH20041215095420 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 340: UPH20041218095641 DB num_groups: 2 Found Groups: 1 Matched Groups: 1
# idx 341: UPH20041221092506 DB num_groups: 1 Found Groups: 3 Matched Groups: 1
# idx 342: UPH20041223102824 DB num_groups: 1 Found Groups: 4 Matched Groups: 1
# idx 343: UPH20041224102120 DB num_groups: 1 Found Groups: 0 Matched Groups: 0
# idx 344: UPH20041225115525 DB num_groups: 1 Found Groups: 3 Matched Groups: 1
# idx 345: UPH20041226111201 DB num_groups: 1 Found Groups: 7 Matched Groups: 1
# idx 346: UPH20041227105318 DB num_groups: 3 Found Groups: 1 Matched Groups: 1
# idx 347: UPH20041228145521 DB num_groups: 2 Found Groups: 1 Matched Groups: 0
# idx 348: UPH20041229094245 DB num_groups: 1 Found Groups: 2 Matched Groups: 1
# idx 349: UPH20041229122714 DB num_groups: 1 Found Groups: 4 Matched Groups: 0
# idx 350: UPH20050102092906 DB num_groups: 2 Found Groups: 1 Matched Groups: 1
# idx 351: UPH20050103105131 DB num_groups: 2 Found Groups: 2 Matched Groups: 1
# idx 352: UPH20050104091808 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 353: UPH20050106104211 DB num_groups: 2 Found Groups: 0 Matched Groups: 0
# idx 354: UPH20050109105847 DB num_groups: 1 Found Groups: 3 Matched Groups: 1
# idx 355: UPH20050110112842 DB num_groups: 1 Found Groups: 6 Matched Groups: 0
# idx 356: UPH20050111134043 DB num_groups: 2 Found Groups: 0 Matched Groups: 0
# idx 357: UPH20050112142816 DB num_groups: 2 Found Groups: 4 Matched Groups: 0
# idx 358: UPH20050113093457 DB num_groups: 3 Found Groups: 5 Matched Groups: 1
# idx 359: UPH20050114091634 DB num_groups: 3 Found Groups: 3 Matched Groups: 1
# idx 360: UPH20050115090221 DB num_groups: 4 Found Groups: 2 Matched Groups: 1
# idx 361: UPH20050115111703 DB num_groups: 4 Found Groups: 3 Matched Groups: 1
# idx 362: UPH20050116092541 DB num_groups: 4 Found Groups: 4 Matched Groups: 1
# idx 363: UPH20050116121118 DB num_groups: 4 Found Groups: 5 Matched Groups: 0
# idx 364: UPH20050118150250 DB num_groups: 6 Found Groups: 3 Matched Groups: 2
# idx 365: UPH20050119105357 DB num_groups: 4 Found Groups: 1 Matched Groups: 0
# idx 366: UPH20050122094506 DB num_groups: 3 Found Groups: 1 Matched Groups: 1
# idx 367: UPH20050123084851 DB num_groups: 3 Found Groups: 2 Matched Groups: 2
# idx 368: UPH20050123090555 DB num_groups: 3 Found Groups: 4 Matched Groups: 1
# idx 369: UPH20050124103333 DB num_groups: 4 Found Groups: 4 Matched Groups: 2
# idx 370: UPH20050125094658 DB num_groups: 4 Found Groups: 3 Matched Groups: 2
# idx 371: UPH20050129094451 DB num_groups: 2 Found Groups: 2 Matched Groups: 1
# idx 372: UPH20050203105327 DB num_groups: 1 Found Groups: 6 Matched Groups: 1
# idx 373: UPH20050206110804 DB num_groups: 4 Found Groups: 6 Matched Groups: 1
# idx 374: UPH20050206111708 DB num_groups: 4 Found Groups: 3 Matched Groups: 1
# idx 375: UPH20050207091338 DB num_groups: 3 Found Groups: 3 Matched Groups: 1
# idx 376: UPH20050208095144 DB num_groups: 4 Found Groups: 1 Matched Groups: 0
# idx 377: UPH20050213095240 DB num_groups: 6 Found Groups: 5 Matched Groups: 4
# idx 378: UPH20050213113429 DB num_groups: 5 Found Groups: 4 Matched Groups: 0
# idx 379: UPH20050215101827 DB num_groups: 3 Found Groups: 5 Matched Groups: 2
# idx 380: UPH20050216101832 DB num_groups: 3 Found Groups: 1 Matched Groups: 0
# idx 381: UPH20050219094206 DB num_groups: 3 Found Groups: 3 Matched Groups: 2
# idx 382: UPH20050221151123 DB num_groups: 2 Found Groups: 3 Matched Groups: 0
# idx 383: UPH20050225085540 DB num_groups: 2 Found Groups: 1 Matched Groups: 0
# idx 384: UPH20050227091721 DB num_groups: 1 Found Groups: 1 Matched Groups: 0
# idx 385: UPH20050228083009 DB num_groups: 0 Found Groups: 2 Matched Groups: 0
# idx 386: UPH20050304085310 DB num_groups: 1 Found Groups: 1 Matched Groups: 0
# idx 387: UPH20050305152741 DB num_groups: 1 Found Groups: 0 Matched Groups: 0
# idx 388: UPH20050306083552 DB num_groups: 1 Found Groups: 2 Matched Groups: 1
# idx 389: UPH20050310093823 DB num_groups: 3 Found Groups: 15 Matched Groups: 3
# idx 390: UPH20050312094224 DB num_groups: 3 Found Groups: 4 Matched Groups: 3
# idx 391: UPH20050313091922 DB num_groups: 3 Found Groups: 3 Matched Groups: 3
# idx 392: UPH20050313110751 DB num_groups: 3 Found Groups: 3 Matched Groups: 2
# idx 393: UPH20050315081152 DB num_groups: 3 Found Groups: 2 Matched Groups: 2
# idx 394: UPH20050316081714 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 395: UPH20050317124547 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 396: UPH20050318131241 DB num_groups: 2 Found Groups: 3 Matched Groups: 2
# idx 397: UPH20050321082253 DB num_groups: 3 Found Groups: 2 Matched Groups: 2
# idx 398: UPH20050323073800 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 399: UPH20050324083713 DB num_groups: 3 Found Groups: 0 Matched Groups: 0
# idx 400: UPH20050325081158 DB num_groups: 4 Found Groups: 3 Matched Groups: 2
# idx 401: UPH20050326121139 DB num_groups: 2 Found Groups: 1 Matched Groups: 1
# idx 402: UPH20050401081339 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 403: UPH20050401091233 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 404: UPH20050401143402 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 405: UPH20050402090630 DB num_groups: 2 Found Groups: 1 Matched Groups: 1
# idx 406: UPH20050403081523 DB num_groups: 3 Found Groups: 3 Matched Groups: 2
# idx 407: UPH20050404072127 DB num_groups: 3 Found Groups: 3 Matched Groups: 2
# idx 408: UPH20050405082255 DB num_groups: 3 Found Groups: 0 Matched Groups: 0
# idx 409: UPH20050405135731 DB num_groups: 3 Found Groups: 3 Matched Groups: 2
# idx 410: UPH20050409064853 DB num_groups: 3 Found Groups: 3 Matched Groups: 2
# idx 411: UPH20050411074904 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 412: UPH20050412074802 DB num_groups: 2 Found Groups: 2 Matched Groups: 1
# idx 413: UPH20050418073714 DB num_groups: 3 Found Groups: 0 Matched Groups: 0
# idx 414: UPH20050420093441 DB num_groups: 2 Found Groups: 0 Matched Groups: 0
# idx 415: UPH20050421072111 DB num_groups: 2 Found Groups: 1 Matched Groups: 1
# idx 416: UPH20050422061659 DB num_groups: 3 Found Groups: 2 Matched Groups: 1
# idx 417: UPH20050422130109 DB num_groups: 1 Found Groups: 2 Matched Groups: 1
# idx 418: UPH20050423084915 DB num_groups: 1 Found Groups: 0 Matched Groups: 0
# idx 419: UPH20050424084024 DB num_groups: 0 Found Groups: 1 Matched Groups: 0
# idx 420: UPH20050426072954 DB num_groups: 1 Found Groups: 2 Matched Groups: 1
# idx 421: UPH20050427081724 DB num_groups: 2 Found Groups: 2 Matched Groups: 1
# idx 422: UPH20050430090206 DB num_groups: 2 Found Groups: 2 Matched Groups: 1
# idx 423: UPH20050501073226 DB num_groups: 2 Found Groups: 3 Matched Groups: 2
# idx 424: UPH20050502091644 DB num_groups: 2 Found Groups: 0 Matched Groups: 0
# idx 425: UPH20050503121323 DB num_groups: 3 Found Groups: 0 Matched Groups: 0
# idx 426: UPH20050504135814 DB num_groups: 3 Found Groups: 3 Matched Groups: 2
# idx 427: UPH20050505075532 DB num_groups: 2 Found Groups: 3 Matched Groups: 2
# idx 428: UPH20050506081338 DB num_groups: 3 Found Groups: 3 Matched Groups: 0
# idx 429: UPH20050506082049 DB num_groups: 3 Found Groups: 3 Matched Groups: 0
# idx 430: UPH20050508102227 DB num_groups: 4 Found Groups: 3 Matched Groups: 1
# idx 431: UPH20050509063449 DB num_groups: 4 Found Groups: 4 Matched Groups: 1
# idx 432: UPH20050510063412 DB num_groups: 6 Found Groups: 6 Matched Groups: 3
# idx 433: UPH20050510063425 DB num_groups: 6 Found Groups: 6 Matched Groups: 2
# idx 434: UPH20050511100313 DB num_groups: 6 Found Groups: 6 Matched Groups: 1
# idx 435: UPH20050512072743 DB num_groups: 6 Found Groups: 5 Matched Groups: 3
# idx 436: UPH20050514085040 DB num_groups: 4 Found Groups: 1 Matched Groups: 0
# idx 437: UPH20050515085906 DB num_groups: 3 Found Groups: 3 Matched Groups: 2
# idx 438: UPH20050516082203 DB num_groups: 2 Found Groups: 4 Matched Groups: 2
# idx 439: UPH20050517075935 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 440: UPH20050518074754 DB num_groups: 2 Found Groups: 1 Matched Groups: 1
# idx 441: UPH20050519074955 DB num_groups: 3 Found Groups: 2 Matched Groups: 1
# idx 442: UPH20050520073239 DB num_groups: 2 Found Groups: 1 Matched Groups: 1
# idx 443: UPH20050521061337 DB num_groups: 1 Found Groups: 0 Matched Groups: 0
# idx 444: UPH20050522062341 DB num_groups: 2 Found Groups: 1 Matched Groups: 0
# idx 445: UPH20050523083423 DB num_groups: 2 Found Groups: 1 Matched Groups: 1
# idx 446: UPH20050524133758 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 447: UPH20050525090416 DB num_groups: 2 Found Groups: 3 Matched Groups: 2
# idx 448: UPH20050526065940 DB num_groups: 3 Found Groups: 0 Matched Groups: 0
# idx 449: UPH20050527082121 DB num_groups: 3 Found Groups: 1 Matched Groups: 1
# idx 450: UPH20050527130128 DB num_groups: 4 Found Groups: 2 Matched Groups: 2
# idx 451: UPH20050528103417 DB num_groups: 1 Found Groups: 2 Matched Groups: 1
# idx 452: UPH20050529082130 DB num_groups: 2 Found Groups: 3 Matched Groups: 2
# idx 453: UPH20050531070025 DB num_groups: 5 Found Groups: 5 Matched Groups: 1
# idx 454: UPH20050601063620 DB num_groups: 4 Found Groups: 2 Matched Groups: 1
# idx 455: UPH20050602143625 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 456: UPH20050603080600 DB num_groups: 2 Found Groups: 6 Matched Groups: 2
# idx 457: UPH20050606134145 DB num_groups: 5 Found Groups: 6 Matched Groups: 5
# idx 458: UPH20050608072328 DB num_groups: 5 Found Groups: 5 Matched Groups: 4
# idx 459: UPH20050609064357 DB num_groups: 4 Found Groups: 4 Matched Groups: 3
# idx 460: UPH20050609102722 DB num_groups: 4 Found Groups: 5 Matched Groups: 4
# idx 461: UPH20050610091028 DB num_groups: 5 Found Groups: 4 Matched Groups: 2
# idx 462: UPH20050610125008 DB num_groups: 5 Found Groups: 4 Matched Groups: 2
# idx 463: UPH20050611091746 DB num_groups: 3 Found Groups: 3 Matched Groups: 2
# idx 464: UPH20050613091121 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 465: UPH20050614064547 DB num_groups: 2 Found Groups: 2 Matched Groups: 0
# idx 466: UPH20050614120038 DB num_groups: 3 Found Groups: 4 Matched Groups: 3
# idx 467: UPH20050615074842 DB num_groups: 4 Found Groups: 3 Matched Groups: 3
# idx 468: UPH20050616064748 DB num_groups: 3 Found Groups: 4 Matched Groups: 2
# idx 469: UPH20050618100735 DB num_groups: 2 Found Groups: 1 Matched Groups: 1
# idx 470: UPH20050619074644 DB num_groups: 2 Found Groups: 1 Matched Groups: 1
# idx 471: UPH20050620075951 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 472: UPH20050620132130 DB num_groups: 2 Found Groups: 3 Matched Groups: 2
# idx 473: UPH20050621100450 DB num_groups: 2 Found Groups: 0 Matched Groups: 0
# idx 474: UPH20050621100859 DB num_groups: 2 Found Groups: 0 Matched Groups: 0
# idx 475: UPH20050621151320 DB num_groups: 2 Found Groups: 3 Matched Groups: 2
# idx 476: UPH20050622074544 DB num_groups: 2 Found Groups: 3 Matched Groups: 2
# idx 477: UPH20050623065358 DB num_groups: 1 Found Groups: 1 Matched Groups: 0
# idx 478: UPH20050623145505 DB num_groups: 1 Found Groups: 0 Matched Groups: 0
# idx 479: UPH20050624083130 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 480: UPH20050624121846 DB num_groups: 0 Found Groups: 1 Matched Groups: 0
# idx 481: UPH20050625090947 DB num_groups: 1 Found Groups: 0 Matched Groups: 0
# idx 482: UPH20050626073953 DB num_groups: 0 Found Groups: 5 Matched Groups: 0
# idx 483: UPH20050627070004 DB num_groups: 1 Found Groups: 0 Matched Groups: 0
# idx 484: UPH20050628080717 DB num_groups: 1 Found Groups: 2 Matched Groups: 1
# idx 485: UPH20050629080850 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 486: UPH20050630073541 DB num_groups: 5 Found Groups: 3 Matched Groups: 3
# idx 487: UPH20050701093943 DB num_groups: 7 Found Groups: 4 Matched Groups: 2
# idx 488: UPH20050701123155 DB num_groups: 5 Found Groups: 8 Matched Groups: 2
# idx 489: UPH20050703085447 DB num_groups: 8 Found Groups: 7 Matched Groups: 3
# idx 490: UPH20050703114403 DB num_groups: 8 Found Groups: 6 Matched Groups: 4
# idx 491: UPH20050705084415 DB num_groups: 8 Found Groups: 6 Matched Groups: 6
# idx 492: UPH20050705151425 DB num_groups: 8 Found Groups: 7 Matched Groups: 5
# idx 493: UPH20050708102416 DB num_groups: 4 Found Groups: 0 Matched Groups: 0
# idx 494: UPH20050709110040 DB num_groups: 5 Found Groups: 3 Matched Groups: 3
# idx 495: UPH20050710130812 DB num_groups: 4 Found Groups: 4 Matched Groups: 3
# idx 496: UPH20050711084938 DB num_groups: 3 Found Groups: 3 Matched Groups: 3
# idx 497: UPH20050711115344 DB num_groups: 3 Found Groups: 6 Matched Groups: 2
# idx 498: UPH20050712102358 DB num_groups: 3 Found Groups: 4 Matched Groups: 3
# idx 499: UPH20050712122206 DB num_groups: 3 Found Groups: 3 Matched Groups: 3
# idx 500: UPH20050713080532 DB num_groups: 4 Found Groups: 3 Matched Groups: 3
# idx 501: UPH20050713121748 DB num_groups: 4 Found Groups: 4 Matched Groups: 2
# idx 502: UPH20050714080910 DB num_groups: 3 Found Groups: 2 Matched Groups: 2
# idx 503: UPH20050714131156 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 504: UPH20050715073926 DB num_groups: 2 Found Groups: 3 Matched Groups: 2
# idx 505: UPH20050715132620 DB num_groups: 2 Found Groups: 3 Matched Groups: 2
# idx 506: UPH20050716074218 DB num_groups: 1 Found Groups: 2 Matched Groups: 1
# idx 507: UPH20050717104315 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 508: UPH20050718095616 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 509: UPH20050719092134 DB num_groups: 0 Found Groups: 1 Matched Groups: 0
# idx 510: UPH20050720092044 DB num_groups: 1 Found Groups: 0 Matched Groups: 0
# idx 511: UPH20050721091110 DB num_groups: 1 Found Groups: 0 Matched Groups: 0
# idx 512: UPH20050722082151 DB num_groups: 1 Found Groups: 0 Matched Groups: 0
# idx 513: UPH20050724083121 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 514: UPH20050725063130 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 515: UPH20050725080837 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 516: UPH20050727070150 DB num_groups: 1 Found Groups: 2 Matched Groups: 1
# idx 517: UPH20050727094916 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 518: UPH20050728075456 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 519: UPH20050729081045 DB num_groups: 3 Found Groups: 4 Matched Groups: 3
# idx 520: UPH20050730081601 DB num_groups: 4 Found Groups: 3 Matched Groups: 2
# idx 521: UPH20050801140945 DB num_groups: 5 Found Groups: 5 Matched Groups: 5
# idx 522: UPH20050801153711 DB num_groups: 5 Found Groups: 5 Matched Groups: 5
# idx 523: UPH20050802081818 DB num_groups: 5 Found Groups: 5 Matched Groups: 5
# idx 524: UPH20050803064852 DB num_groups: 4 Found Groups: 3 Matched Groups: 3
# idx 525: UPH20050803102053 DB num_groups: 3 Found Groups: 3 Matched Groups: 3
# idx 526: UPH20050804094317 DB num_groups: 3 Found Groups: 3 Matched Groups: 3
# idx 527: UPH20050804122202 DB num_groups: 4 Found Groups: 3 Matched Groups: 3
# idx 528: UPH20050806132346 DB num_groups: 3 Found Groups: 3 Matched Groups: 3
# idx 529: UPH20050807071338 DB num_groups: 4 Found Groups: 3 Matched Groups: 3
# idx 530: UPH20050808115603 DB num_groups: 4 Found Groups: 4 Matched Groups: 4
# idx 531: UPH20050809075148 DB num_groups: 4 Found Groups: 3 Matched Groups: 3
# idx 532: UPH20050809112259 DB num_groups: 4 Found Groups: 3 Matched Groups: 3
# idx 533: UPH20050810074436 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 534: UPH20050810122729 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 535: UPH20050811134201 DB num_groups: 3 Found Groups: 4 Matched Groups: 2
# idx 536: UPH20050812103435 DB num_groups: 4 Found Groups: 2 Matched Groups: 0
# idx 537: UPH20050812113942 DB num_groups: 4 Found Groups: 0 Matched Groups: 0
# idx 538: UPH20050813090243 DB num_groups: 2 Found Groups: 2 Matched Groups: 0
# idx 539: UPH20050814092357 DB num_groups: 2 Found Groups: 1 Matched Groups: 1
# idx 540: UPH20050816074515 DB num_groups: 2 Found Groups: 3 Matched Groups: 1
# idx 541: UPH20050817071338 DB num_groups: 2 Found Groups: 1 Matched Groups: 1
# idx 542: UPH20050817113635 DB num_groups: 2 Found Groups: 1 Matched Groups: 1
# idx 543: UPH20050818070713 DB num_groups: 2 Found Groups: 2 Matched Groups: 1
# idx 544: UPH20050818133919 DB num_groups: 3 Found Groups: 3 Matched Groups: 1
# idx 545: UPH20050819145419 DB num_groups: 5 Found Groups: 4 Matched Groups: 2
# idx 546: UPH20050822101134 DB num_groups: 2 Found Groups: 3 Matched Groups: 2
# idx 547: UPH20050822134548 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 548: UPH20050824071609 DB num_groups: 3 Found Groups: 3 Matched Groups: 2
# idx 549: UPH20050825121910 DB num_groups: 3 Found Groups: 4 Matched Groups: 2
# idx 550: UPH20050826093631 DB num_groups: 3 Found Groups: 3 Matched Groups: 1
# idx 551: UPH20050827101645 DB num_groups: 4 Found Groups: 4 Matched Groups: 2
# idx 552: UPH20050828112129 DB num_groups: 4 Found Groups: 3 Matched Groups: 2
# idx 553: UPH20050829075537 DB num_groups: 5 Found Groups: 4 Matched Groups: 2
# idx 554: UPH20050829130741 DB num_groups: 5 Found Groups: 3 Matched Groups: 1
# idx 555: UPH20050830072842 DB num_groups: 4 Found Groups: 3 Matched Groups: 1
# idx 556: UPH20050830134140 DB num_groups: 3 Found Groups: 3 Matched Groups: 0
# idx 557: UPH20050831073458 DB num_groups: 3 Found Groups: 3 Matched Groups: 0
# idx 558: UPH20050831131635 DB num_groups: 3 Found Groups: 3 Matched Groups: 0
# idx 559: UPH20050902081828 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 560: UPH20050903084553 DB num_groups: 1 Found Groups: 2 Matched Groups: 1
# idx 561: UPH20050903085706 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 562: UPH20050904141602 DB num_groups: 1 Found Groups: 2 Matched Groups: 1
# idx 563: UPH20050905074228 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 564: UPH20050905120533 DB num_groups: 1 Found Groups: 2 Matched Groups: 1
# idx 565: UPH20050906101927 DB num_groups: 1 Found Groups: 0 Matched Groups: 0
# idx 566: UPH20050906114703 DB num_groups: 1 Found Groups: 0 Matched Groups: 0
# idx 567: UPH20050907064824 DB num_groups: 2 Found Groups: 1 Matched Groups: 0
# idx 568: UPH20050907121613 DB num_groups: 2 Found Groups: 0 Matched Groups: 0
# idx 569: UPH20050908075130 DB num_groups: 2 Found Groups: 1 Matched Groups: 1
# idx 570: UPH20050908115255 DB num_groups: 2 Found Groups: 1 Matched Groups: 1
# idx 571: UPH20050910094458 DB num_groups: 2 Found Groups: 3 Matched Groups: 2
# idx 572: UPH20050913072509 DB num_groups: 3 Found Groups: 2 Matched Groups: 1
# idx 573: UPH20050914073326 DB num_groups: 1 Found Groups: 2 Matched Groups: 1
# idx 574: UPH20050916114910 DB num_groups: 1 Found Groups: 2 Matched Groups: 1
# idx 575: UPH20050917092449 DB num_groups: 2 Found Groups: 1 Matched Groups: 1
# idx 576: UPH20050919091219 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 577: UPH20050921074928 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 578: UPH20050921115700 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 579: UPH20050922070250 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 580: UPH20050923085355 DB num_groups: 1 Found Groups: 3 Matched Groups: 1
# idx 581: UPH20050923141739 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 582: UPH20050924121346 DB num_groups: 2 Found Groups: 1 Matched Groups: 1
# idx 583: UPH20050925104025 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 584: UPH20050926090528 DB num_groups: 3 Found Groups: 2 Matched Groups: 1
# idx 585: UPH20050928072019 DB num_groups: 2 Found Groups: 2 Matched Groups: 0
# idx 586: UPH20050928122305 DB num_groups: 2 Found Groups: 1 Matched Groups: 0
# idx 587: UPH20050929071301 DB num_groups: 2 Found Groups: 3 Matched Groups: 1
# idx 588: UPH20050929140855 DB num_groups: 2 Found Groups: 2 Matched Groups: 1
# idx 589: UPH20051001093508 DB num_groups: 1 Found Groups: 0 Matched Groups: 0
# idx 590: UPH20051001122743 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 591: UPH20051002081923 DB num_groups: 1 Found Groups: 1 Matched Groups: 0
# idx 592: UPH20051003072716 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 593: UPH20051003102008 DB num_groups: 1 Found Groups: 0 Matched Groups: 0
# idx 594: UPH20051007135442 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 595: UPH20051010080321 DB num_groups: 2 Found Groups: 0 Matched Groups: 0
# idx 596: UPH20051010142702 DB num_groups: 1 Found Groups: 0 Matched Groups: 0
# idx 597: UPH20051011080452 DB num_groups: 1 Found Groups: 0 Matched Groups: 0
# idx 598: UPH20051012081335 DB num_groups: 2 Found Groups: 2 Matched Groups: 0
# idx 599: UPH20051012100153 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 600: UPH20051013081738 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 601: UPH20051013102208 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 602: UPH20051014112612 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 603: UPH20051015082306 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 604: UPH20051015105306 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 605: UPH20051016091727 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 606: UPH20051017080208 DB num_groups: 2 Found Groups: 2 Matched Groups: 1
# idx 607: UPH20051017140344 DB num_groups: 2 Found Groups: 1 Matched Groups: 1
# idx 608: UPH20051018075904 DB num_groups: 1 Found Groups: 7 Matched Groups: 0
# idx 609: UPH20051019123144 DB num_groups: 2 Found Groups: 2 Matched Groups: 1
# idx 610: UPH20051020082252 DB num_groups: 1 Found Groups: 0 Matched Groups: 0
# idx 611: UPH20051026091151 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 612: UPH20051027084853 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 613: UPH20051028084350 DB num_groups: 0 Found Groups: 2 Matched Groups: 0
# idx 614: UPH20051029103557 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# ...
# idx 2948: UPH20170413062015 DB num_groups: 2 Found Groups: 3 Matched Groups: 0
# idx 2949: UPH20170414061902 DB num_groups: 1 Found Groups: 2 Matched Groups: 1
# idx 2950: UPH20170414152440 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 2951: UPH20170416102311 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 2952: UPH20170417114524 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 2953: UPH20170418092433 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 2954: UPH20170419084500 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 2955: UPH20170420074018 DB num_groups: 2 Found Groups: 1 Matched Groups: 0
# idx 2956: UPH20170421110108 DB num_groups: 3 Found Groups: 0 Matched Groups: 0
# idx 2957: UPH20170422102036 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 2958: UPH20170423081250 DB num_groups: 3 Found Groups: 4 Matched Groups: 3
# idx 2959: UPH20170424091704 DB num_groups: 3 Found Groups: 4 Matched Groups: 1
# idx 2960: UPH20170425073000 DB num_groups: 3 Found Groups: 2 Matched Groups: 1
# idx 2961: UPH20170426082038 DB num_groups: 3 Found Groups: 3 Matched Groups: 3
# idx 2962: UPH20170427073330 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 2963: UPH20170429065620 DB num_groups: 3 Found Groups: 3 Matched Groups: 3
# idx 2964: UPH20170430081500 DB num_groups: 2 Found Groups: 0 Matched Groups: 0
# idx 2965: UPH20170501155417 DB num_groups: 1 Found Groups: 2 Matched Groups: 1
# idx 2966: UPH20170502070201 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 2967: UPH20170505114648 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 2968: UPH20170506073356 DB num_groups: 2 Found Groups: 3 Matched Groups: 2
# idx 2969: UPH20170509081500 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 2970: UPH20170510064507 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 2971: UPH20170511083523 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 2972: UPH20170512090359 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 2973: UPH20170513110813 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 2974: UPH20170514074402 DB num_groups: 0 Found Groups: 6 Matched Groups: 0
# idx 2975: UPH20170515064837 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 2976: UPH20170516080000 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 2977: UPH20170516084500 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 2978: UPH20170517095040 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 2979: UPH20170518144634 DB num_groups: 2 Found Groups: 2 Matched Groups: 0
# idx 2980: UPH20170520093557 DB num_groups: 3 Found Groups: 0 Matched Groups: 0
# idx 2981: UPH20170521074731 DB num_groups: 3 Found Groups: 0 Matched Groups: 0
# idx 2982: UPH20170522080832 DB num_groups: 4 Found Groups: 4 Matched Groups: 4
# idx 2983: UPH20170523080000 DB num_groups: 4 Found Groups: 4 Matched Groups: 4
# idx 2984: UPH20170524093352 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 2985: UPH20170525075437 DB num_groups: 2 Found Groups: 1 Matched Groups: 1
# idx 2986: UPH20170526081150 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 2987: UPH20170527075710 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 2988: UPH20170528085048 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 2989: UPH20170529074430 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 2990: UPH20170530094517 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 2991: UPH20170531075512 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 2992: UPH20170601075542 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 2993: UPH20170602075607 DB num_groups: 1 Found Groups: 2 Matched Groups: 1
# idx 2994: UPH20170603125247 DB num_groups: 1 Found Groups: 0 Matched Groups: 0
# idx 2995: UPH20170604092034 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 2996: UPH20170605091215 DB num_groups: 2 Found Groups: 1 Matched Groups: 1
# idx 2997: UPH20170606085124 DB num_groups: 1 Found Groups: 3 Matched Groups: 0
# idx 2998: UPH20170607080934 DB num_groups: 1 Found Groups: 5 Matched Groups: 1
# idx 2999: UPH20170608090454 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3000: UPH20170609101856 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3001: UPH20170610095406 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3002: UPH20170611074053 DB num_groups: 0 Found Groups: 1 Matched Groups: 0
# idx 3003: UPH20170612074258 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3004: UPH20170613074542 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3005: UPH20170614081747 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3006: UPH20170615075348 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 3007: UPH20170616073427 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 3008: UPH20170617090030 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 3009: UPH20170618074825 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 3010: UPH20170619073000 DB num_groups: 2 Found Groups: 3 Matched Groups: 1
# idx 3011: UPH20170620080601 DB num_groups: 2 Found Groups: 3 Matched Groups: 1
# idx 3012: UPH20170621073016 DB num_groups: 3 Found Groups: 3 Matched Groups: 3
# idx 3013: UPH20170622074958 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 3014: UPH20170623075609 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 3015: UPH20170626125300 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3016: UPH20170629083814 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3017: UPH20170630092438 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3018: UPH20170702125011 DB num_groups: 1 Found Groups: 0 Matched Groups: 0
# idx 3019: UPH20170703073601 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3020: UPH20170704114000 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3021: UPH20170705062005 DB num_groups: 0 Found Groups: 5 Matched Groups: 0
# idx 3022: UPH20170706082812 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3023: UPH20170707073459 DB num_groups: 1 Found Groups: 2 Matched Groups: 1
# idx 3024: UPH20170707124500 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3025: UPH20170708090000 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3026: UPH20170708132457 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3027: UPH20170709082003 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 3028: UPH20170710084353 DB num_groups: 3 Found Groups: 2 Matched Groups: 2
# idx 3029: UPH20170711081007 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3030: UPH20170713063931 DB num_groups: 2 Found Groups: 5 Matched Groups: 2
# idx 3031: UPH20170714065410 DB num_groups: 3 Found Groups: 5 Matched Groups: 3
# idx 3032: UPH20170717134000 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3033: UPH20170718073020 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3034: UPH20170719080455 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3035: UPH20170720105452 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3036: UPH20170721083015 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3037: UPH20170722084505 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3038: UPH20170723104338 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3039: UPH20170724080032 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3040: UPH20170725112735 DB num_groups: 0 Found Groups: 1 Matched Groups: 0
# idx 3041: UPH20170726075854 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3042: UPH20170727082415 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3043: UPH20170728111016 DB num_groups: 1 Found Groups: 0 Matched Groups: 0
# idx 3044: UPH20170728112019 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3045: UPH20170729081500 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3046: UPH20170730072541 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3047: UPH20170731075104 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3048: UPH20170801085302 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3049: UPH20170803123822 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3050: UPH20170805103941 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3051: UPH20170806082256 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3052: UPH20170807075606 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3053: UPH20170809093803 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3054: UPH20170811090657 DB num_groups: 1 Found Groups: 2 Matched Groups: 1
# idx 3055: UPH20170813095945 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3056: UPH20170814070852 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3057: UPH20170815095943 DB num_groups: 1 Found Groups: 3 Matched Groups: 1
# idx 3058: UPH20170816064007 DB num_groups: 2 Found Groups: 1 Matched Groups: 0
# idx 3059: UPH20170818152128 DB num_groups: 2 Found Groups: 2 Matched Groups: 0
# idx 3060: UPH20170819095908 DB num_groups: 2 Found Groups: 1 Matched Groups: 0
# idx 3061: UPH20170820080743 DB num_groups: 3 Found Groups: 3 Matched Groups: 1
# idx 3062: UPH20170821093821 DB num_groups: 3 Found Groups: 4 Matched Groups: 1
# idx 3063: UPH20170822101557 DB num_groups: 3 Found Groups: 4 Matched Groups: 1
# idx 3064: UPH20170823070243 DB num_groups: 4 Found Groups: 3 Matched Groups: 1
# idx 3065: UPH20170824092627 DB num_groups: 3 Found Groups: 3 Matched Groups: 1
# idx 3066: UPH20170825091416 DB num_groups: 3 Found Groups: 3 Matched Groups: 1
# idx 3067: UPH20170826095055 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 3068: UPH20170827092649 DB num_groups: 2 Found Groups: 4 Matched Groups: 1
# idx 3069: UPH20170828073052 DB num_groups: 1 Found Groups: 2 Matched Groups: 0
# idx 3070: UPH20170829064500 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 3071: UPH20170830085636 DB num_groups: 3 Found Groups: 5 Matched Groups: 2
# idx 3072: UPH20170831093559 DB num_groups: 4 Found Groups: 7 Matched Groups: 3
# idx 3073: UPH20170901090051 DB num_groups: 4 Found Groups: 4 Matched Groups: 2
# idx 3074: UPH20170902101105 DB num_groups: 3 Found Groups: 3 Matched Groups: 3
# idx 3075: UPH20170903094326 DB num_groups: 5 Found Groups: 6 Matched Groups: 2
# idx 3076: UPH20170905124142 DB num_groups: 6 Found Groups: 6 Matched Groups: 4
# idx 3077: UPH20170906075407 DB num_groups: 5 Found Groups: 5 Matched Groups: 3
# idx 3078: UPH20170907085651 DB num_groups: 4 Found Groups: 5 Matched Groups: 2
# idx 3079: UPH20170909124224 DB num_groups: 3 Found Groups: 4 Matched Groups: 3
# idx 3080: UPH20170910115519 DB num_groups: 3 Found Groups: 9 Matched Groups: 2
# idx 3081: UPH20170911090408 DB num_groups: 2 Found Groups: 5 Matched Groups: 1
# idx 3082: UPH20170912081655 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3083: UPH20170913100306 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3084: UPH20170914091513 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3085: UPH20170915121651 DB num_groups: 1 Found Groups: 16 Matched Groups: 1
# idx 3086: UPH20170916074800 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3087: UPH20170917074958 DB num_groups: 1 Found Groups: 2 Matched Groups: 1
# idx 3088: UPH20170918080620 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3089: UPH20170919100044 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3090: UPH20170920095515 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3091: UPH20170920120031 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 3092: UPH20170921081238 DB num_groups: 2 Found Groups: 0 Matched Groups: 0
# idx 3093: UPH20170922133056 DB num_groups: 1 Found Groups: 0 Matched Groups: 0
# idx 3094: UPH20170923100010 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3095: UPH20170924100024 DB num_groups: 2 Found Groups: 3 Matched Groups: 2
# idx 3096: UPH20170925080123 DB num_groups: 3 Found Groups: 6 Matched Groups: 3
# idx 3097: UPH20170926084323 DB num_groups: 3 Found Groups: 0 Matched Groups: 0
# idx 3098: UPH20170926130000 DB num_groups: 3 Found Groups: 3 Matched Groups: 3
# idx 3099: UPH20170927132235 DB num_groups: 3 Found Groups: 0 Matched Groups: 0
# idx 3100: UPH20170928094426 DB num_groups: 3 Found Groups: 5 Matched Groups: 3
# idx 3101: UPH20170929090351 DB num_groups: 3 Found Groups: 0 Matched Groups: 0
# idx 3102: UPH20170930153518 DB num_groups: 3 Found Groups: 13 Matched Groups: 3
# idx 3103: UPH20171002120129 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 3104: UPH20171003080000 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 3105: UPH20171005115529 DB num_groups: 2 Found Groups: 3 Matched Groups: 2
# idx 3106: UPH20171006115917 DB num_groups: 2 Found Groups: 0 Matched Groups: 0
# idx 3107: UPH20171008105459 DB num_groups: 0 Found Groups: 5 Matched Groups: 0
# idx 3108: UPH20171009080443 DB num_groups: 0 Found Groups: 9 Matched Groups: 0
# idx 3109: UPH20171010075851 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3110: UPH20171012080508 DB num_groups: 0 Found Groups: 3 Matched Groups: 0
# idx 3111: UPH20171013105400 DB num_groups: 0 Found Groups: 2 Matched Groups: 0
# idx 3112: UPH20171014081200 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3113: UPH20171015081739 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3114: UPH20171015145048 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3115: UPH20171015154153 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3116: UPH20171016080739 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3117: UPH20171017083755 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3118: UPH20171018082026 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3119: UPH20171019082809 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3120: UPH20171021112457 DB num_groups: 0 Found Groups: 5 Matched Groups: 0
# idx 3121: UPH20171022095500 DB num_groups: 1 Found Groups: 3 Matched Groups: 1
# idx 3122: UPH20171025085621 DB num_groups: 2 Found Groups: 0 Matched Groups: 0
# idx 3123: UPH20171027093028 DB num_groups: 2 Found Groups: 0 Matched Groups: 0
# idx 3124: UPH20171029122725 DB num_groups: 2 Found Groups: 0 Matched Groups: 0
# idx 3125: UPH20171030094127 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 3126: UPH20171101090637 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3127: UPH20171102143410 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3128: UPH20171103102016 DB num_groups: 0 Found Groups: 1 Matched Groups: 0
# idx 3129: UPH20171104084906 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3130: UPH20171105085644 DB num_groups: 0 Found Groups: 1 Matched Groups: 0
# idx 3131: UPH20171106091653 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3132: UPH20171107090049 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3133: UPH20171112115127 DB num_groups: 0 Found Groups: 7 Matched Groups: 0
# idx 3134: UPH20171113094523 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3135: UPH20171117100519 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3136: UPH20171117121500 DB num_groups: 2 Found Groups: 2 Matched Groups: 2
# idx 3137: UPH20171118111647 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3138: UPH20171119101517 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3139: UPH20171122123830 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3140: UPH20171124100540 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3141: UPH20171125145044 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3142: UPH20171126110429 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3143: UPH20171128103829 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3144: UPH20171208121932 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3145: UPH20171217125654 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3146: UPH20171218101500 DB num_groups: 0 Found Groups: 0 Matched Groups: 0
# idx 3147: UPH20171226101222 DB num_groups: 1 Found Groups: 1 Matched Groups: 1
# idx 3148: UPH20171227100332 DB num_groups: 1 Found Groups: 0 Matched Groups: 0
# idx 3149: UPH20171228122714 DB num_groups: 0 Found Groups: 0 Matched Groups: 0

# %%
root_dir
# Out:
# '/globalscratch/users/n/s/nsayez/Classification_dataset/2002-2019_2/'

# %%
# image_out_dict

# %%
out_json_dir = 'feb2023'
out_json_filename = 'dataset'

# out_json_filename = 'dataset'

# %%
# with open(f'{root_dir}/2002-2019/{out_json_dir}/{out_json_filename}.json', 'w') as f:
# with open(f'{root_dir}/ManualAnnotation/{out_json_filename}.json', 'w') as f:
# with open(f'{root_dir}/{out_json_filename}.json', 'w') as f:
with open(f'{root_dir}/test/{out_json_filename}.json', 'w') as f:
    json.dump(image_out_dict, f, cls=NpEncoder)

# %%
import json
# with open(f'{root_dir}/{out_json_filename}.json', 'r') as f:
with open(f'{root_dir}/test/{out_json_filename}.json', 'r') as f:
# with open(f'{root_dir}/2002-2019/{out_json_dir}/{out_json_filename}.json', 'r') as f:
# with open(f'{root_dir}/ManualAnnotation/{out_json_filename}.json', 'r') as f:
    image_out_dict = json.load(f)

# %% [markdown]
# # Dataset Statistics

# %%
# 1) analyse the distributions

classes = ['A','B','C','D','E','F','G','H','I','J','X']

distribs = {c: 0 for c in classes}
group_types = {}
group_types2 = {c:{} for c in classes}

for bn, img_dict in tqdm(image_out_dict.items()):
    groups = img_dict['groups']
    
    for i, g in enumerate(groups):
        cur_c = g["Zurich"]
        distribs[cur_c] +=1
        
        new_group_infos= {
            'angle': img_dict['angle'],
            'deltashapeX': img_dict['deltashapeX'],
            'deltashapeY':img_dict['deltashapeY'],
            'centroid_px': g['centroid_px'],
            'centroid_Lat': g['centroid_Lat'],
            'centroid_Lon': g['centroid_Lon'],
            'members': g['members'],
            'members_mean_px': g['members_mean_px'],
            'angular_excentricity_rad': g['angular_excentricity_rad'],
            'angular_excentricity_deg': g['angular_excentricity_deg'],
            'Zurich': g['Zurich'],
            'McIntosh': g['McIntosh'],   
        }
        
        new_goup_id = bn + '_' + str(i)
        group_types[new_goup_id] = new_group_infos
        group_types2[cur_c][new_goup_id] = new_group_infos
        
    
print(distribs)
print()
# print(group_types2)
# Out:
#   0%|          | 0/1856 [00:00<?, ?it/s]
# {'A': 421, 'B': 520, 'C': 805, 'D': 798, 'E': 177, 'F': 16, 'G': 79, 'H': 315, 'I': 0, 'J': 743, 'X': 15}

# %%
group_based_dataset = deepcopy(group_types)
group_based_dataset2 = deepcopy(group_types2)

# %%
First2superFirst = {"A":"A",
                    "B":"B",
                    "C":"C",
                    "D":"SuperGroup",
                    "E":"SuperGroup",
                    "F":"SuperGroup",
                    "H":"H",
                    "X":"X"
                   }
Second2superSecond = {"x":"x",
                      "r":"r",
                      "s": "sym",
                      "h": "sym",
                      "a": "asym",
                      "k": "asym",
                     }
Third2superThird = {"x": "x",
                    "o": "o",
                    "i": "frag",
                    "c": "frag",
                   }

def add_superclasses(group_dict):
    cpy = deepcopy(group_dict)    
    # print(cpy)

    cpy["SuperClass"] = {
        "1": First2superFirst[group_dict["McIntosh"][0]],
        "2": Second2superSecond[group_dict["McIntosh"][1]],
        "3": Third2superThird[group_dict["McIntosh"][2]],
    }
    
    return cpy
    
    

grp_to_remove = []
group_based_dataset_superclasses = {}
for g in tqdm(group_based_dataset):
    try : 
        group = group_based_dataset[g]
        # print(group)
        group = add_superclasses(group)
#         print(group)
        group_based_dataset_superclasses[g] = group
        
    except KeyError:
        print(g)
        print(group_based_dataset[g])
        if group_based_dataset[g]["McIntosh"] == '   ':
            print( "error")
            grp_to_remove.append((g,group_based_dataset[g]['Zurich']))

for k,k_type in grp_to_remove:
    group_based_dataset.pop(k)
    group_based_dataset2[k_type].pop(k)

# group_based_dataset_superclasses
# Out:
#   0%|          | 0/3889 [00:00<?, ?it/s]
# UPH20040722080136_1
# {'angle': 6.950210373029591, 'deltashapeX': 226, 'deltashapeY': 226, 'centroid_px': array([1763.98468838,  789.79392226]), 'centroid_Lat': -0.19138280535545324, 'centroid_Lon': 0.8858795170464564, 'members': [[789.1715265866209, 1766.2315608919382], [805.4, 1705.56], [804.0, 1700.5]], 'members_mean_px': array([ 799.5238422 , 1724.09718696]), 'angular_excentricity_rad': 0.8332981619101842, 'angular_excentricity_deg': 47.74446775346269, 'Zurich': 'G', 'McIntosh': '   '}
# error

# %% [markdown]
# ## Split per type

# %%
distribs2 = {c:0 for c in classes}
group_types2 = {c:{} for c in classes}

for grp_id, grp_dict in tqdm(group_based_dataset_superclasses.items()):
    cur_c = grp_dict["Zurich"]
    group_types2[cur_c][grp_id] = grp_dict
        
# group_types2
# Out:
#   0%|          | 0/3888 [00:00<?, ?it/s]

# %% [markdown]
# ## Step 2:  Split groups among train, val, test sets

# %%
import random


def splitPerc(l, perc):
    # Turn percentages into values between 0 and 1
    splits = np.cumsum(perc)/100.

    if splits[-1] != 1:
        raise ValueError("percents don't add up to 100")

    # Split doesn't need last percent, it will just take what is left
    splits = splits[:-1]

    # Turn values into indices
    splits *= len(l)

    # Turn double indices into integers.
    # CAUTION: numpy rounds to closest EVEN number when a number is halfway
    # between two integers. So 0.5 will become 0 and 1.5 will become 2!
    # If you want to round up in all those cases, do
    # splits += 0.5 instead of round() before casting to int
    splits = splits.round().astype(np.int)

    return np.split(l, splits)

splits = ['train', 'val', 'test']

splits_percentages = [70, 15, 15]

assert np.array(splits_percentages).sum() == 100

group_based_dataset_superclasses_splits = {sp:{} for sp in splits}

for t, type_dict in group_types2.items():
    list_type_groups = list(type_dict.keys()) 
    # shuffle
    random.shuffle(list_type_groups)
    
    indices = np.array(range(len(list_type_groups)))
    
    s = splitPerc(indices, splits_percentages)

    # take percentage and fill group_based_dataset
    for i, sp in enumerate(splits):
        split_indices = s[i]
        split_groups = [list_type_groups[j] for j in split_indices]
        
#         print(split_groups)
        for g in  split_groups:
            group_based_dataset_superclasses_splits[sp][g] = type_dict[g]

# %%
# group_based_dataset_superclasses_splits

# %%
final_json = "dataset_nosplits"
# with open(f'{root_dir}/2002-2019/{out_json_dir}/{final_json}.json', 'w') as f:
# with open(f'{root_dir}/ManualAnnotation/{final_json}.json', 'w') as f:
# with open(f'{root_dir}/{final_json}.json', 'w') as f:
with open(f'{root_dir}/test/{final_json}.json', 'w') as f:
    json.dump(group_based_dataset_superclasses, f, cls=NpEncoder)
final_json_split = "dataset_final"
# with open(f'{root_dir}/2002-2019/{out_json_dir}/{final_json_split}.json', 'w') as f:
# with open(f'{root_dir}/ManualAnnotation/{final_json_split}.json', 'w') as f:
with open(f'{root_dir}/test/{final_json_split}.json', 'w') as f:
    json.dump(group_based_dataset_superclasses_splits, f, cls=NpEncoder)

# %% [markdown]
# ## Compare model inputs

# %%
from omegaconf import OmegaConf
from hydra.utils import instantiate

# %%
cropper_transform_idx = 0

#load the config file
cfg1_orig = OmegaConf.load(f'test.yaml')

cfg2_focus_noRand = OmegaConf.load(f'test.yaml')
cfg2_focus_noRand.transforms[cropper_transform_idx].focus_on_group = True

cfg3_nofocus_rand = OmegaConf.load(f'test.yaml')
cfg3_nofocus_rand.transforms[cropper_transform_idx].focus_on_group = False
cfg3_nofocus_rand.transforms[cropper_transform_idx].random_move = True
cfg3_nofocus_rand.transforms[cropper_transform_idx].random_move_percent = .2

cfg4_focus_rand = OmegaConf.load(f'test.yaml')
cfg4_focus_rand.transforms[cropper_transform_idx].focus_on_group = True
cfg4_focus_rand.transforms[cropper_transform_idx].random_move = True
cfg4_focus_rand.transforms[cropper_transform_idx].random_move_percent = .2

# %%
tr_orig = [instantiate(t) for t in cfg1_orig.transforms]
tr_focus_noRand = [instantiate(t) for t in cfg2_focus_noRand.transforms]
tr_nofocus_rand = [instantiate(t) for t in cfg3_nofocus_rand.transforms]
tr_focus_rand = [instantiate(t) for t in cfg4_focus_rand.transforms]

# %%
root_dir
# Out:
# '/globalscratch/users/n/s/nsayez/Classification_dataset/2002-2019_2/'

# %%
# %load_ext autoreload
# %autoreload 2
from transform_utilities import *

def create_circular_mask(h, w, center=None, radius=None):

    if center is None: # use the middle of the image
        center = (int(w/2), int(h/2))
    if radius is None: # use the smallest distance between the center and image walls
        radius = min(center[0], center[1], w-center[0], h-center[1])

    Y, X = np.ogrid[:h, :w]
    dist_from_center = np.sqrt((X - center[0])**2 + (Y-center[1])**2)

    mask = dist_from_center <= radius
    return mask

# get mask contaoining only components at given coordinates using regionprops
def get_mask_from_coords(mask, coords):
    mask = mask.copy()
    mask[~mask] = 0
    mask = mask.astype(np.uint8)
    props = regionprops(mask)
    for p in props:
        if p.centroid not in coords:
            mask[p.coords[:,0], p.coords[:,1]] = 0
    return mask


from datetime import datetime, timedelta

def create_sample( grp_info, img_path, mask_path, conf_path):
    sample = {}
    sample['image'] = (io.imread(img_path)).astype(float) 
    header = fits.open(img_path)[0].header
    center = np.array(sample['image'].shape)//2
    radius = header['SOLAR_R']
    
    
    basename = os.path.basename(img_path).split('.')[0]
    sample['name'] = basename
    
    flip_time = "2003-03-08T00:00:00"
    date = c_utils.whitelight_to_datetime(basename)
    datetime_str = c_utils.datetime_to_db_string(date).replace(' ', 'T')
    print(datetime_str)
    should_flip = (datetime.fromisoformat(datetime_str) - datetime.fromisoformat(flip_time)) < timedelta(0)
    sample['should_flip'] = should_flip
    

    sample['solar_disk'] = create_circular_mask( sample['image'].shape[1], sample['image'].shape[0] ,center,radius)
    sample['mask'] = io.imread(mask_path)#.astype(float)
    
    sample['members'] = np.array(grp_info['members'])
    sample['members_mean_px'] = np.array(grp_info['members_mean_px'])
    
    sample['confidence_map'] = np.load(conf_path)#.astype(float)


    sample['solar_angle'] = grp_info['angle']
    sample['deltashapeX'] = grp_info['deltashapeX']
    sample['deltashapeY'] = grp_info['deltashapeY']
    
  
    
    
    sample['angular_excentricity'] = np.array([grp_info["angular_excentricity_deg"]])
    sample['centroid_px'] = np.array(grp_info["centroid_px"])
    sample['excentricity_map'] = sample['solar_disk'].copy()

    sample['centroid_Lat'] = np.array([grp_info["centroid_Lat"]])
    print(should_flip)
#     should_flip=True
    if should_flip:
        sample['image'] = np.flip(sample['image'],axis=0)
        sample['solar_disk'] = np.flip(sample['solar_disk'],axis=0)
        sample['mask'] = np.flip(sample['mask'],axis=0)
        sample['confidence_map'] = np.flip(sample['confidence_map'],axis=0)
        sample['excentricity_map'] = np.flip(sample['excentricity_map'],axis=0)
    
    

    return sample

def grp_refresh(value):
    grp_name = list(group_based_dataset_superclasses.keys())[grp_slider.value]
    grp = group_based_dataset_superclasses[grp_name]
    grp_superclass = grp['SuperClass']

    # print(grp)

    img_bn = grp_name.split('_')[0]
#     img_path = f'{root_dir}/2002-2019/image/{img_bn}.FTS'
#     mask_path = f'{root_dir}/2002-2019/T400-T350-Alternating_pen_um/{img_bn}.png'
#     img_path = f'/globalscratch/users/n/s/nsayez/Classification_dataset/2002-2019/image/{img_bn}.FTS'
    img_path = f'/globalscratch/users/n/s/nsayez/Classification_dataset/2002-2019_2/image/{img_bn}.FTS'
    mask_path = f'{root_dir}/T425-T375-T325_fgbg/{img_bn}.png'
    conf_path = f'{root_dir}/T425-T375-T325_fgbg/{img_bn}_proba_map.npy'
    # img_path = f'/globalscratch/users/n/s/nsayez/deepsun_bioblue/ManualAnnotation/image/{img_bn}.FTS'
    # mask_path = f'/globalscratch/users/n/s/nsayez/deepsun_bioblue/ManualAnnotation/GroundTruth/{img_bn}.png'

    sample = create_sample(grp, img_path, mask_path, conf_path)
    
    sampleV1 = sample.copy()
    for t in tr_orig:
        sampleV1 = t(**sampleV1)
    sampleV2 = sample.copy()
    for t in tr_focus_noRand:
        sampleV2 = t(**sampleV2)
    sampleV3 = sample.copy()
    for t in tr_nofocus_rand:
        sampleV3 = t(**sampleV3)
    sampleV4 = sample.copy()
    for t in tr_focus_rand:
        sampleV4 = t(**sampleV4)

    # print(sample)
    ax2[0].set_title(f"{grp_name}:\n {grp_superclass['1']}{grp_superclass['2']}{grp_superclass['3']}")
    ax2[0].imshow(sampleV1['image'], origin='lower', cmap='gray', vmin=0)
    ax2[1].set_title(f"orig")
    ax2[1].imshow(sampleV1['image'], origin='lower', cmap='gray', vmin=0)
    ax2[2].set_title(f"focus_noRand")
    ax2[2].imshow(sampleV2['image'], origin='lower', cmap='gray', vmin=0)
    ax2[3].set_title(f"nofocus_rand")
    ax2[3].imshow(sampleV3['image'], origin='lower', cmap='gray', vmin=0)
    ax2[4].set_title(f"focus_rand")
    ax2[4].imshow(sampleV4['image'], origin='lower', cmap='gray', vmin=0)
    
    if msk_cb.value:
        # pass
        
        
        ax2[1].imshow(sampleV1['confidence_map'], origin='lower', alpha=0.5, cmap='jet', interpolation='none')
        ax2[2].imshow(sampleV2['confidence_map'], origin='lower', alpha=0.5, cmap='jet', interpolation='none')
        ax2[3].imshow(sampleV3['confidence_map'], origin='lower', alpha=0.5, cmap='jet', interpolation='none')
        ax2[4].imshow(sampleV4['confidence_map'], origin='lower', alpha=0.5, cmap='jet', interpolation='none')

#         ax2[1].imshow(sampleV1['mask'], origin='lower', alpha=0.5, cmap='jet', interpolation='none')
#         ax2[2].imshow(sampleV2['mask'], origin='lower', alpha=0.5, cmap='jet', interpolation='none')
#         ax2[3].imshow(sampleV3['mask'], origin='lower', alpha=0.5, cmap='jet', interpolation='none')
#         ax2[4].imshow(sampleV4['mask'], origin='lower', alpha=0.5, cmap='jet', interpolation='none')
    if grp_msk_cb.value:
        # pass

        ax2[1].imshow(sampleV1['group_mask'], origin='lower', alpha=0.5, cmap='jet', interpolation='none')
        ax2[2].imshow(sampleV2['group_mask'], origin='lower', alpha=0.5, cmap='jet', interpolation='none')
        ax2[3].imshow(sampleV3['group_mask'], origin='lower', alpha=0.5, cmap='jet', interpolation='none')
        ax2[4].imshow(sampleV4['group_mask'], origin='lower', alpha=0.5, cmap='jet', interpolation='none')
#         ax2[1].imshow(sampleV1['group_mask'], origin='lower', alpha=0.5, cmap='jet', interpolation='none')
#         ax2[2].imshow(sampleV2['group_mask'], origin='lower', alpha=0.5, cmap='jet', interpolation='none')
#         ax2[3].imshow(sampleV3['group_mask'], origin='lower', alpha=0.5, cmap='jet', interpolation='none')
#         ax2[4].imshow(sampleV4['group_mask'], origin='lower', alpha=0.5, cmap='jet', interpolation='none')


# 1773
grp_slider = widgets.IntSlider(min=0, max=len(group_based_dataset_superclasses)-1, step=1, value=1667, description='Group')
msk_cb = widgets.Checkbox(value=True, description='Mask', disabled=False, indent=False)
grp_msk_cb = widgets.Checkbox(value=True, description='GroupMask', disabled=False, indent=False)

grp_slider.observe(grp_refresh, 'value')
msk_cb.observe(grp_refresh, 'value')
grp_msk_cb.observe(grp_refresh, 'value')

plt.ioff()
fig2,ax2 = plt.subplots(1,5,figsize=(8,4))
grp_refresh(None)
plt.ion()

display(widgets.VBox([widgets.HBox([grp_slider, msk_cb, grp_msk_cb]), fig2.canvas]))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2010-07-01T08:00:00
# False
# VBox(children=(HBox(children=(IntSlider(value=1667, description='Group', max=3887), Checkbox(value=True, descr…
# 2011-10-02T07:19:00
# False
# 2011-10-02T07:19:00
# False
# 2011-10-02T07:19:00
# False
# 2011-10-03T07:50:00
# False
# 2011-10-03T07:50:00
# False
# 2011-10-03T07:50:00
# False
# 2011-10-03T07:50:00
# False
# 2011-10-07T08:33:00
# False
# 2011-10-07T08:33:00
# False
# 2011-10-07T08:33:00
# False
# 2011-10-13T08:49:00
# False
# 2011-10-13T08:49:00
# False
# 2011-10-13T08:49:00
# False
# 2011-10-13T08:49:00
# False
# 2011-10-13T08:49:00
# False
# 2011-10-13T08:49:00
# False
# 2011-10-13T08:49:00
# False
# 2011-10-13T08:49:00
# False
# 2011-10-13T08:49:00
# False
# 2011-10-14T08:29:00
# False
# 2011-10-14T08:29:00
# False
# 2011-10-14T08:29:00
# False
# 2011-10-14T08:29:00
# False
# 2011-10-14T08:29:00
# False
# 2011-10-14T08:29:00
# False
# 2011-10-14T08:29:00
# False
# 2011-10-15T08:43:00
# False
# 2011-10-15T08:43:00
# False
# 2011-10-15T08:43:00
# False
# 2011-10-15T08:43:00
# False
# 2011-10-15T08:43:00
# False
# 2011-10-15T08:43:00
# False
# 2011-10-15T08:43:00
# False
# 2011-10-16T09:47:00
# False
# 2011-10-16T09:47:00
# False
# 2011-10-16T09:47:00
# False
# 2011-10-16T09:47:00
# False
# 2011-10-16T09:47:00
# False
# 2011-10-16T09:47:00
# False
# 2011-10-17T13:18:00
# False
# 2011-10-17T13:18:00
# False
# 2011-10-17T13:18:00
# False
# 2011-10-17T13:18:00
# False
# 2011-10-17T13:18:00
# False
# 2011-10-19T08:12:00
# False
# 2011-10-19T08:12:00
# False
# 2011-10-19T08:12:00
# False

# %%
#erreur pr index 1773

# %%
# for grp_slder in range(0, len(group_based_dataset_superclasses.keys())-1):
def grp_refresh(value):
    grp_name = list(group_based_dataset_superclasses.keys())[grp_slider.value]
    grp = group_based_dataset_superclasses[grp_name]
    grp_superclass = grp['SuperClass']

    # print(grp)

    img_bn = grp_name.split('_')[0]
#     img_path = f'{root_dir}/2002-2019/image/{img_bn}.FTS'
#     mask_path = f'{root_dir}/2002-2019/T400-T350-Alternating_pen_um/{img_bn}.png'
    img_path = f'/globalscratch/users/n/s/nsayez/Classification_dataset/2002-2019/image/{img_bn}.FTS'
    mask_path = f'{root_dir}/T425-T375-T325_fgbg/{img_bn}.png'
    # img_path = f'/globalscratch/users/n/s/nsayez/deepsun_bioblue/ManualAnnotation/image/{img_bn}.FTS'
    # mask_path = f'/globalscratch/users/n/s/nsayez/deepsun_bioblue/ManualAnnotation/GroundTruth/{img_bn}.png'

    sample = create_sample(grp, img_path, mask_path)
    
    sampleV1 = sample.copy()
    for t in tr_orig:
        sampleV1 = t(**sampleV1)

    # get the sunspots that are in sampleV1['mask'] but not in sampleV1['group_mask'] 
    diff_mask = sampleV1['mask'] - sampleV1['group_mask']
    if np.sum(diff_mask) > 0:
        print(f"Group {grp_name} has sunspots that are not in the group mask")

    ax2[0].set_title(f"{grp_name}:\n {grp_superclass['1']}{grp_superclass['2']}{grp_superclass['3']}")
    ax2[0].imshow(sampleV1['image'], origin='lower', cmap='gray', vmin=0)
    ax2[1].set_title(f"Whole Mask")
    ax2[1].imshow(sampleV1['mask'], origin='lower', cmap='gray', vmin=0)
    ax2[2].set_title(f"Group Mask")
    ax2[2].imshow(sampleV1['group_mask'], origin='lower', cmap='gray', vmin=0)
    ax2[3].set_title(f"Unwanted Sunspots")
    ax2[3].imshow(diff_mask, origin='lower', cmap='gray', vmin=0)

grp_slider = widgets.IntSlider(min=0, max=len(group_based_dataset_superclasses)-1, step=1, value=1773, description='Group')
msk_cb = widgets.Checkbox(value=True, description='Mask', disabled=False, indent=False)
grp_msk_cb = widgets.Checkbox(value=True, description='GroupMask', disabled=False, indent=False)

grp_slider.observe(grp_refresh, 'value')
msk_cb.observe(grp_refresh, 'value')
grp_msk_cb.observe(grp_refresh, 'value')

plt.ioff()
fig2,ax2 = plt.subplots(1,4,figsize=(8,4))
grp_refresh(None)
plt.ion()

display(widgets.VBox([widgets.HBox([grp_slider, msk_cb, grp_msk_cb]), fig2.canvas]))
# Out:
# Group UPH20111019081228_1 has sunspots that are not in the group mask
# VBox(children=(HBox(children=(IntSlider(value=1773, description='Group', max=3337), Checkbox(value=True, descr…

# %%
import concurrent.futures

# for idx in tqdm(range(0, len(group_based_dataset_superclasses.keys())-1)):
def is_isolated(idx):
    grp_name = list(group_based_dataset_superclasses.keys())[idx]
    grp = group_based_dataset_superclasses[grp_name]
    grp_superclass = grp['SuperClass']

    # print(grp)

    img_bn = grp_name.split('_')[0]
    img_path = f'{root_dir}/2002-2019/image/{img_bn}.FTS'
    mask_path = f'{root_dir}/2002-2019/T400-T350-Alternating_pen_um/{img_bn}.png'
    # img_path = f'/globalscratch/users/n/s/nsayez/deepsun_bioblue/ManualAnnotation/image/{img_bn}.FTS'
    # mask_path = f'/globalscratch/users/n/s/nsayez/deepsun_bioblue/ManualAnnotation/GroundTruth/{img_bn}.png'

    sample = create_sample(grp, img_path, mask_path)
    
    sampleV1 = sample.copy()
    for t in tr_orig:
        sampleV1 = t(**sampleV1)

    # get the sunspots that are in sampleV1['mask'] but not in sampleV1['group_mask'] 
    diff_mask = sampleV1['mask'] - sampleV1['group_mask']
    if np.sum(diff_mask>0) > 0:
        return True
        # print(f"Group {grp_name} has sunspots that are not in the group mask")
    return False

num_NotIsolated_groups = 0
NotIsolated_groups = []

num_cpu = 16
with concurrent.futures.ProcessPoolExecutor(max_workers=int(num_cpu)) as executor:

    for i in tqdm(executor.map(is_isolated, range(0, len(group_based_dataset_superclasses.keys())-1))):
        if i:
            num_NotIsolated_groups += 1
            NotIsolated_groups.append(i)


proportion = num_NotIsolated_groups / len(group_based_dataset_superclasses.keys())
print(f"Proportion of cases with sunspots that are not in the group mask: {proportion}")
# Out:
# 0it [00:00, ?it/s]
# Proportion of cases with sunspots that are not in the group mask: 0.15133601324190116

# %% [markdown]
# #### To get this proportion the following must be taken into account:
#
# #### We search for the presence of mask elements in the crop that do not belong to the mask of group elements
#
# #### This means that the counter increases in case of:
#
#     1. There is an actual other group in the crop
#     2. There is a segmentation FP in the crop
#
# #### On the other hand, The counter does not increases in case of:
#
#     1. Segmentation FN external to the group.

# %% [markdown]
# # Vérifier que pour les images de classes B, il n'y a pas de pénombre.
#
# Parcourir les groupes de classe B,
#
# regarder les masques de groupe
# `
# verifier que lle masque de groupe ne contient pas de pénombre.

# %% [markdown]
# # Degrade masks

# %% [markdown]
# # Poubelle

# %%
import matplotlib

colors = ['tab:blue','tab:orange','tab:green','tab:red',
          'tab:purple','tab:brown','tab:pink',
          'tab:olive','tab:cyan']

def new_refresh(value):
    basename = os.path.basename(wl_list[img_slider.value]).split(".")[0]
    m, h = utils.open_and_add_celestial(wl_list[img_slider.value])
    mask = io.imread(os.path.join(masks_dir,basename+".png"))
    mask2 = mask.copy()
    mask2[mask2>0] = 1

    sunspots_sk, sunspots_areas = get_sunspots3(h,m, mask2, sky_coords=True)
    sunspots_pixel, _ = get_sunspots3(h, m, mask2, sky_coords=False)

    sk_Lon = sunspots_sk.lon.rad
    sk_Lat = sunspots_sk.lat.rad
    sk_LatLon = np.stack((sk_Lat,sk_Lon),axis=1)

    nan_indexes = np.unique(np.argwhere(np.isnan(sk_LatLon))[:,0])
    clean = (~np.isnan(sk_Lon) & ~np.isnan(sk_Lat))
    if len(nan_indexes) > 0:
        sunspots_sk = sunspots_sk[clean]
        sunspots_areas = (np.array(sunspots_areas)[clean]).tolist()
        sk_LatLon = sk_LatLon [clean]

    global ms_model
    ms_model = Mean_Shift(look_distance, kernel_bandwidthLon, kernel_bandwidthLat, sunspots_sk.radius.km[0], n_iterations)
    ms_model.fit(sk_LatLon, sunspots_areas)
    ms_centroids = ms_model.centroids

    sk_sequ_meanshift = SkyCoord(ms_centroids[:,1]*u.rad, ms_centroids[:,0]*u.rad , frame=frames.HeliographicCarrington,
                        obstime=m.date, observer="earth")
    wcs2 = WCS(h)
    pix_centers_meanshift = np.array(skycoord_to_pixel(sk_sequ_meanshift, wcs2, origin=0)).T.tolist()

    ms_classifications = ms_model.predict(sk_LatLon)
    # print(ms_classifications.shape, np.unique(ms_classifications))

    ms_group_sunspots = [(sk_LatLon[ms_classifications == c].tolist()) for c in np.unique(ms_classifications)] 
    ms_group_sunspots_px = [sunspots_pixel[ms_classifications == c].tolist() for c in np.unique(ms_classifications)]
    # print(len(ms_group_sunspots))

    #latitude and longitudes in radians
    extreme_values = -np.pi, np.pi, 0, 2*np.pi

    # print(sk_LatLon.shape)
    ax3[0].clear(), ax3[1].clear(), ax3[2].clear()
    ax3[0].set_title(basename)
    ax3[0].imshow(m.data,cmap='gray')
    ax3[0].imshow(mask,cmap='jet',alpha=0.5)
    ax3[0].invert_yaxis()

    ax3[1].imshow(m.data,cmap='gray')
    ax3[1].invert_yaxis()
    for i in range(len(ms_group_sunspots)):
        c = colors[np.unique(ms_classifications)[i]%len(colors)]
        # c = colors[ms_classifications[i]%len(colors)]
        cur = np.array(ms_group_sunspots_px[i])
        ms_centers = pix_centers_meanshift[i]
        ax3[1].scatter(ms_centers[0],ms_centers[1], s=10, c=c, marker='x')
        ax3[1].scatter(cur[:,1], cur[:,0], color=c, s=2)

    ax3[2].scatter(ms_centroids[:,1], ms_centroids[:,0], s=1)
    ax3[2].set_ylim(extreme_values[0], extreme_values[1])
    ax3[2].set_xlim(extreme_values[2], extreme_values[3])

    # ax5[1].scatter(sk_LatLon[:,1], sk_LatLon[:,0], s=1)
    # ax5[1].set_xlim(0, 2*np.pi)
    # ax5[1].set_ylim(-np.pi/2, np.pi/2)
    
    
    hist_refresh(None)

def hist_refresh(change):
    # if (xlims0, ylims0) != (0, 1):
    xlims0 = ax5[0].get_xlim()
    ylims0 = ax5[0].get_ylim()
    # print(xlims0, ylims0)

    global ms_model
    # print(ms_model.history)
    step = hist_slider.value
    ax5[0].clear()
    ax5[0].set_title('History step {}'.format(step))
    for i in range(len(ms_model.history[step])):
        cur_width = ms_model.get_area_weighted_ellipsis_width( ms_model.areas[i], ms_model.areas)
        cur_height = kernel_bandwidthLat
        # if (ms_model.data[i][0] <= 0.28 and ms_model.data[i][0] >= 0.25) and (ms_model.data[i][1] >= 1.45 and ms_model.data[i][1] <= 1.48):
        #     print(cur_width, cur_height)
        ellipsis = matplotlib.patches.Ellipse((ms_model.history[step][i,1], ms_model.history[step][i,0]), 2*cur_width, 2*cur_height, fill=False, color='red')
        # ellipsis = matplotlib.patches.Ellipse((ms_model.history[step][i,1], ms_model.history[step][i,0]), 2*kernel_bandwidthLon, 2*kernel_bandwidthLat, fill=False, color='red')
        ax5[0].add_patch(ellipsis)
    ax5[0].scatter(ms_model.history[step][:,1], ms_model.history[step][:,0], s=1)
    ax5[0].set_ylim(-np.pi/2, np.pi/2)
    ax5[0].set_xlim(0, 2*np.pi)
    # ax5.set_xlim(np.min(ms_model.data[:,1]), np.max(ms_model.data[:,1]))
    if (xlims0, ylims0) != ((0., 1.),(0., 1.)):
        ax5[0].set_xlim(xlims0)
        ax5[0].set_ylim(ylims0)
    

look_distance = .1 # How far to look for neighbours.
kernel_bandwidthLon = .35  # Longitude Kernel parameter.
kernel_bandwidthLat = .08  # Latitude Kernel parameter.
n_iterations = 20 # Number of iterations
    
ms_model = None

img_slider = widgets.IntSlider(min=0, max=len(wl_list)-1, step=1, value=3, description='Group')
msk_cb = widgets.Checkbox(value=False, description='Mask', disabled=False, indent=False)

img_slider.observe(new_refresh, 'value')
msk_cb.observe(new_refresh, 'value')

hist_slider = widgets.IntSlider(min=0, max=n_iterations-1, step=1, value=0, description='History')
hist_slider.observe(hist_refresh, 'value')

plt.ioff()
fig3,ax3 = plt.subplots(1,3,figsize=(12,3))
fig5,ax5 = plt.subplots(1,2,figsize=(10,3))
new_refresh(None)
hist_refresh(None)
plt.ion()


display(widgets.VBox([widgets.HBox([img_slider, msk_cb]), fig3.canvas]))
display(widgets.VBox([widgets.HBox([hist_slider]), fig5.canvas]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [31], line 111
#     107 n_iterations = 20 # Number of iterations
#     109 ms_model = None
# --> 111 img_slider = widgets.IntSlider(min=0, max=len(wl_list)-1, step=1, value=3, description='Group')
#     112 msk_cb = widgets.Checkbox(value=False, description='Mask', disabled=False, indent=False)
#     114 img_slider.observe(new_refresh, 'value')
#
# NameError: name 'wl_list' is not defined
